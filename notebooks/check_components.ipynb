# %%
import os
from crewai.flow import Flow, start, router, or_
from typing import Optional
import sys
import pprint
from pathlib import Path
                    
ROOT_DIR = Path().resolve().parent
if str(ROOT_DIR) not in sys.path:
    sys.path.insert(0, str(ROOT_DIR))

from crews.input_validator.crew import InputValidatorCrew

# %%
for v in ("HTTP_PROXY","HTTPS_PROXY","ALL_PROXY","http_proxy","https_proxy","all_proxy"):
    os.environ.pop(v, None)
os.environ.setdefault("NO_PROXY", "127.0.0.1,localhost")
os.environ["CREWAI_DISABLE_TELEMETRY"] = "true"
os.environ["OTEL_SDK_DISABLED"] = "true"
# log utile se serve
os.environ["LITELLM_LOG"] = "DEBUG"

# %%
print("🚀 Avvio Crew di Validazione Input...\n")
crew = InputValidatorCrew()
# Out:
# 🚀 Avvio Crew di Validazione Input...

# %%
# crew.__dict__
title_remove = 'CrewAI un framework per i tuoi agenti AI'
example_remove = 'Promuovere l\'uso di CrewAi come framework per la collaborazione di moteplici agenti AI'

# %%
# import litellm
# litellm._turn_on_debug()

# %%
state = await crew.kickoff(title = title_remove, 
                     abstract = example_remove, 
                     structure = ['introduzione', 'svolgimento', 'conclusione'])
# Out:
# ╭──────────────────────────────────────────────── Flow Execution ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: InputValidatorFlow                                                                                       │
# │  ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Avvio asincrono del flow InputValidatorFlow                                                 ]8;id=824337;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=966401;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#132\132]8;;\
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# └── 🧠 Starting Flow...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#  Flow started with ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── 🧠 Starting Flow...
# └── 🔄 Running: verify_title
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🔁 Inizio del flow di validazione input                                                         ]8;id=357255;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=570876;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#30\30]8;;\
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# └── ✅ Completed: verify_title
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# └── 🔄 Running: decide_abstract_presence
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     ✅ Abstract già fornito. Procedo a migliorarlo.                                                 ]8;id=281221;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=761756;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#38\38]8;;\
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# └── ✅ Completed: decide_abstract_presence
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# └── 🔄 Running: abstract_modifier
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Attivo la crew per migliorare l’abstract esistente...                                        ]8;id=892162;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=954007;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#62\62]8;;\
# INFO     [OUTPUT abstract] Il framework CrewAI è stato concepito per facilitare la progettazione,        ]8;id=515270;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=484291;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#74\74]8;;\
#          l’implementazione e la gestione di sistemi multi‑agente intelligenti. Grazie a un’architettura
#          modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo
#          semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza,
#          sicurezza e prestazioni elevate. In questo articolo presentiamo i principi fondamentali del
#          framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto
#          decisionale alla gestione autonoma di processi complessi. Vengono inoltre analizzati casi d’uso
#          reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale
#          collaborativa.
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# └── ✅ Completed: abstract_modifier
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# ├── ✅ Completed: abstract_modifier
# └── 🔄 Running: migliora_struttura
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🎯 Attivazione Crew per miglioramento struttura                                                 ]8;id=521379;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=315692;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#79\79]8;;\
# INFO     ✅ Crew completata, output : ["Introduzione", "Motivazioni", "Architettura", "Interfaccia di    ]8;id=418259;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=191147;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#91\91]8;;\
#          programmazione", "Principi fondamentali", "Uso pratico", "Casi d'uso", "Potenzialità future",
#          "Conclusioni"]
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# ├── ✅ Completed: abstract_modifier
# └── ✅ Completed: migliora_struttura
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# ├── ✅ Completed: abstract_modifier
# ├── ✅ Completed: migliora_struttura
# └── 🔄 Running: conclude
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🏁 Flow terminato con successo.                                                                 ]8;id=254272;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=113391;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#97\97]8;;\
# INFO     Titolo: CrewAI un framework per i tuoi agenti AI                                                ]8;id=977293;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=736919;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#98\98]8;;\
# INFO     Abstract: Il framework CrewAI è stato concepito per facilitare la progettazione,                ]8;id=173588;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=737722;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#99\99]8;;\
#          l’implementazione e la gestione di sistemi multi‑agente intelligenti. Grazie a un’architettura
#          modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo
#          semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza,
#          sicurezza e prestazioni elevate. In questo articolo presentiamo i principi fondamentali del
#          framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto
#          decisionale alla gestione autonoma di processi complessi. Vengono inoltre analizzati casi d’uso
#          reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale
#          collaborativa.
# INFO     Struttura finale: ['Introduzione', 'Motivazioni', 'Architettura', 'Interfaccia di              ]8;id=621027;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=503783;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#100\100]8;;\
#          programmazione', 'Principi fondamentali', 'Uso pratico', "Casi d'uso", 'Potenzialità future',
#          'Conclusioni']
# INFO     📊 Riepilogo log: {'log_lines': 23, 'log_levels': {'INFO': 23}, 'level_ratio': {'INFO':        ]8;id=333369;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py\flow.py]8;;\:]8;id=951237;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/input_validator/flow.py#110\110]8;;\
#          100.0}, 'transitions': {}, 'duration_seconds': 1132.0, 'avg_interval_seconds':
#          51.45454545454545, 'first_entry': '2025-09-05 16:30:10', 'last_entry': '2025-09-05 16:49:02',
#          'top_messages': [('2025-09-05 16:30:10 | INFO     | InputValidatorFlow | 🚀 Avvio asincrono
#          del flow InputValidatorFlow', 1), ('2025-09-05 16:30:10 | INFO     | InputValidatorFlow | 🔁
#          Inizio del flow di validazione input', 1), ('2025-09-05 16:30:10 | INFO     |
#          InputValidatorFlow | ✅ Abstract già fornito. Procedo a migliorarlo.', 1), ('2025-09-05
#          16:30:10 | INFO     | InputValidatorFlow | 🚀 Attivo la crew per migliorare l’abstract
#          esistente...', 1), ('2025-09-05 16:30:27 | INFO     | InputValidatorFlow | [OUTPUT abstract]
#          CrewAI è un framework open‑source progettato per orchestrare, coordinare e monitorare più
#          agenti intelligenti in scenari complessi. La sua architettura modulare, basata su grafi di
#          task, un linguaggio di descrizione delle interazioni e un runtime scalabile, supporta sia
#          agenti basati su modelli di linguaggio che su reti neurali specializzate. Grazie a
#          un’interfaccia di programmazione semplice, gli sviluppatori possono definire workflow, gestire
#          dipendenze e monitorare le performance in tempo reale. In questo articolo presentiamo la
#          struttura di CrewAI, i suoi componenti principali e una serie di casi d’uso reali,
#          evidenziando come il framework riduca la complessità di integrazione e aumenti l’efficacia
#          della collaborazione tra agenti AI. Il nostro obiettivo è promuovere l’adozione di CrewAI,
#          offrendo una piattaforma robusta e flessibile per la collaborazione di multipli agenti AI.',
#          1)]}
# 🌊 Flow: InputValidatorFlow
#     ID: a3838d08-8b68-4f89-ac66-10cd7df9b56d
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# ├── ✅ Completed: abstract_modifier
# ├── ✅ Completed: migliora_struttura
# └── ✅ Completed: conclude
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Flow Finished: InputValidatorFlow
# ├── Flow Method Step
# ├── ✅ Completed: verify_title
# ├── ✅ Completed: decide_abstract_presence
# ├── ✅ Completed: abstract_modifier
# ├── ✅ Completed: migliora_struttura
# └── ✅ Completed: conclude

# %%
crew.flow.plot(filename='InputValidatorFlow')
# Out:
# Plot saved as InputValidatorFlow.html

# %%
from crews.writing.crew import WritingCrew

crew2 = WritingCrew()

# %%
state2 = await crew2.kickoff(title = state.__dict__['title'], 
                             abstract = state.__dict__['abstract'], 
                             structure = state.__dict__['structure'])

# state = {'id': '6e75b347-3dfb-4c83-b9f7-fad1289d5d6a',
#  'title': 'CrewAI un framework per i tuoi agenti AI',
#  'abstract': "CrewAI rappresenta una pietra miliare nell'ambito del machine learning collaborativo, offrendo uno strumento innovativo per la gestione coordinata di più agenti AI. Questo framework è stato progettato con l'intento di semplificare e ottimizzare le interazioni tra sistemi intelligenti multipli, consentendo loro di operare in modo sincronizzato verso un obiettivo comune. CrewAI si distingue per la sua flessibilità, permettendo agli sviluppatori di personalizzare agenti AI secondo necessità specifiche e integrarli senza sforzo all'interno di ambienti complessi.\n\nAttraverso l'adozione di standard aperti e architetture modulabili, CrewAI facilita un ambiente collaborativo dove gli agenti possono comunicare ed elaborare informazioni condivise in tempo reale. Questo non solo aumenta l'efficienza delle operazioni AI ma permette anche una gestione più intuitiva del processo decisionale collettivo. In sintesi, CrewAI emerge come un framework indispensabile per chiunque cerchi di promuovere e implementare soluzioni basate su agenti multipli AI, garantendo al contempo semplicità nell'integrazione e maggiore potenza nel raggiungimento degli obiettivi condivisi.",
#  'structure': ['Introduzione','Motivazioni','Tecnologia','Implementazione e Integrazione','Efficienza Operativa e Decisione Collettiva','Conclusioni'],
#  'current_section_index': 0,
#  'paragraphs': {},
#  'section_summaries': {},
#  'code_instructions': {},
#  'code_snippets': {},
#  'edited_article': '',
#  'supervision_report': '',
#  'sources': [],
#  'logs': []}


# state2 = await crew2.kickoff(title = state['title'], 
#                              abstract = state['abstract'], 
#                              structure = state['structure'])
# Out:
# ╭──────────────────────────────────────────────── Flow Execution ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Starting Flow Execution                                                                                        │
# │  Name: WritingArticleFlow                                                                                       │
# │  ID: ae9c9371-cb01-4860-8796-9b3d97813cb0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Avvio asincrono del flow WritingArticleFlow                                                 ]8;id=898518;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=454523;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#142\142]8;;\
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# └── 🧠 Starting Flow...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#  Flow started with ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── 🧠 Starting Flow...
# └── 🔄 Running: start_article
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 📝 Inizio generazione sezioni articolo...
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# └── ✅ Completed: start_article
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# └── 🔄 Running: check_written_sections
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# └── ✅ Completed: check_written_sections
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# └── 🔄 Running: write_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Attivo la crew per la generazione sezioni articolo...                                        ]8;id=731669;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=635466;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#44\44]8;;\
# INFO     📝 Scrittura sezione Introduzione                                                               ]8;id=490450;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=341877;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#53\53]8;;\
# # Agent: Technical Writer
# ## Task: Scrivi la sezione 'Introduzione' per l’articolo intitolato 'CrewAI un framework per i tuoi agenti AI' e avente abstract 'Il framework CrewAI è stato concepito per facilitare la progettazione, l’implementazione e la gestione di sistemi multi‑agente intelligenti. Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni elevate. In questo articolo presentiamo i principi fondamentali del framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto decisionale alla gestione autonoma di processi complessi. Vengono inoltre analizzati casi d’uso reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale collaborativa.'. Mantieni coerenza con le sezioni precedenti, riassunte in: {}
# Se ritieni utile includere codice Python, aggiungi in fondo una riga che inizia con: [CODICE_RICHIESTO][START] istruzione dettagliata in linguaggio naturale. [END]
#
#
#
# # Agent: Technical Writer
# ## Final Answer:
# **Introduzione**
#
# L’intelligenza artificiale ha compiuto passi da gigante negli ultimi anni, ma la maggior parte delle soluzioni commerciali e di ricerca rimane ancora focalizzata su singoli modelli monolitici. In scenari complessi—come l’analisi di grandi volumi di dati, la generazione di contenuti creativi o la gestione autonoma di processi industriali—una singola intelligenza spesso non è sufficiente: serve un ecosistema di agenti specializzati che collaborano in modo coerente e scalabile.
#
# CrewAI nasce proprio per colmare questa lacuna. Il framework è stato concepito con l’obiettivo di **facilitare la progettazione, l’implementazione e la gestione di sistemi multi‑agente intelligenti**. Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni elevate.
#
# Tra le caratteristiche distintive di CrewAI troviamo:
#
# * **Composizione dinamica**: i team di agenti possono essere creati, modificati o distrutti in tempo reale, adattandosi alle mutevoli esigenze del task.
# * **Ruoli e responsabilità chiaramente definiti**: ogni agente è dotato di un profilo di competenze, consentendo una distribuzione ottimale del lavoro e riducendo i conflitti di sovrapposizione.
# * **Pianificazione e coordinamento**: il motore di orchestrazione gestisce la sequenza delle attività, le dipendenze e la sincronizzazione tra agenti, senza richiedere agli sviluppatori di scrivere logica complessa di scheduling.
# * **Sicurezza e audit**: tutti i messaggi tra agenti sono tracciati, e i permessi possono essere configurati a livello di ruolo, garantendo trasparenza e conformità a normative specifiche.
#
# L’articolo che segue si articola in tre parti principali:
#
# 1. **Principi fondamentali di CrewAI** – descrizione dell’architettura, dei componenti chiave (Crew, Agent, Task, Scheduler) e delle best‑practice per la definizione dei ruoli.
# 2. **Costruire soluzioni personalizzate** – esempi pratici, dalla creazione di un team per il supporto decisionale alla gestione autonoma di un workflow complesso, con focus su integrazioni esterne (API, database, sistemi legacy).
# 3. **Casi d’uso reali e prospettive future** – analisi di progetti pilota in ambito finanziario, sanitario e industriale, oltre a una panoramica delle potenzialità emergenti (integrazione con modelli di linguaggio di nuova generazione, apprendimento continuo, evoluzione autonoma dei ruoli).
#
# Con CrewAI, gli sviluppatori non devono più preoccuparsi di gestire manualmente le interazioni tra agenti; il framework si occupa di orchestrare, monitorare e ottimizzare l’intero ecosistema, consentendo di concentrarsi sul valore aggiunto delle singole competenze AI.
#
# [CODICE_RICHIESTO][START] Scrivi un frammento di codice Python che dimostri come creare un crew con due agenti (un “DataAnalyst” e un “Summarizer”), assegnare loro un task di analisi di un dataset e generare un report riassuntivo. Assicurati di includere l’inizializzazione del crew, la definizione dei ruoli, l’invio del task e la stampa dell’output finale. [END]
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c03b50>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x13579e4a0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c6eec0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c039a0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x13579f340>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c6e200>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135ce66b0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135d35270>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c03ca0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c6e410>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135d515d0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135cd78b0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c03490>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x1351bd3f0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135d89390>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x13579d270>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c66bf0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135c02800>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135db68c0>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x135cd7f70>, 'Connection to telemetry.crewai.com timed out. (connect timeout=30)'))
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# └── ✅ Completed: write_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# └── 🔄 Running: code_generation_node
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# └── ✅ Completed: code_generation_node
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# └── 🔄 Running: write_code
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Attivo la crew per la generazione del codice interno alla sezione Introduzione               ]8;id=460052;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=669545;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#78\78]8;;\
# INFO     📝 Generazione codice...                                                                        ]8;id=886513;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=669191;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#86\86]8;;\
# # Agent: Python Developer
# ## Task: Sulla base della seguente istruzione testuale: "Scrivi un frammento di codice Python che dimostri come creare un crew con due agenti (un “DataAnalyst” e un “Summarizer”), assegnare loro un task di analisi di un dataset e generare un report riassuntivo. Assicurati di includere l’inizializzazione del crew, la definizione dei ruoli, l’invio del task e la stampa dell’output finale." genera o modifica il codice Python completo, ben strutturato e commentato. Non spiegare il codice: restituiscilo come puro blocco di codice eseguibile. Se non ricevi istruzioni restituisci una stringa vuota ''
#
#
#
# # Agent: Python Developer
# ## Final Answer:
# ```python
# from crewai import Agent, Task, Crew, Process
# import pandas as pd
# import numpy as np
#
# # Create a sample dataset
# df = pd.DataFrame({
#     "Sales": np.random.randint(50, 200, 10),
#     "Profit": np.random.uniform(5.0, 20.0, 10),
#     "Region": np.random.choice(["North", "South", "East", "West"], 10)
# })
#
# # Define the agents
# data_analyst = Agent(
#     role="Data Analyst",
#     goal="Perform exploratory data analysis on the dataset and generate insights.",
#     backstory="Experienced in statistical analysis and data visualization.",
#     verbose=True,
#     allow_delegation=False
# )
#
# summarizer = Agent(
#     role="Summarizer",
#     goal="Summarize the insights from the Data Analyst into a concise report.",
#     backstory="Skilled in clear communication and report writing.",
#     verbose=True,
#     allow_delegation=False
# )
#
# # Define the tasks
# analysis_task = Task(
#     description="Analyze the dataset and provide key findings.",
#     expected_output="A detailed analysis of the dataset.",
#     agent=data_analyst,
#     context=df.head().to_dict()
# )
#
# summary_task = Task(
#     description="Create a summary report based on the analysis.",
#     expected_output="A concise summary report.",
#     agent=summarizer,
#     context="The analysis results from the previous step."
# )
#
# # Create and run the crew
# crew = Crew(
#     agents=[data_analyst, summarizer],
#     tasks=[analysis_task, summary_task],
#     process=Process.sequential,
#     verbose=2
# )
#
# result = crew.kickoff()
# print("\nFinal Report:\n", result)
# ```
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# └── ✅ Completed: write_code
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# └── 🔄 Running: upgrade_code
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🚀 Attivo la crew per la modifica del codice generato per la sezione Introduzione               ]8;id=273590;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=659837;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#98\98]8;;\
# INFO     📝 Modifiche al codice...                                                                      ]8;id=758213;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=591487;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#106\106]8;;\
# # Agent: Senior Code Reviewer
# ## Task: Revisiona il seguente codice Python:
# ```python ```python
# from crewai import Agent, Task, Crew, Process
# import pandas as pd
# import numpy as np
#
# # Create a sample dataset
# df = pd.DataFrame({
#     "Sales": np.random.randint(50, 200, 10),
#     "Profit": np.random.uniform(5.0, 20.0, 10),
#     "Region": np.random.choice(["North", "South", "East", "West"], 10)
# })
#
# # Define the agents
# data_analyst = Agent(
#     role="Data Analyst",
#     goal="Perform exploratory data analysis on the dataset and generate insights.",
#     backstory="Experienced in statistical analysis and data visualization.",
#     verbose=True,
#     allow_delegation=False
# )
#
# summarizer = Agent(
#     role="Summarizer",
#     goal="Summarize the insights from the Data Analyst into a concise report.",
#     backstory="Skilled in clear communication and report writing.",
#     verbose=True,
#     allow_delegation=False
# )
#
# # Define the tasks
# analysis_task = Task(
#     description="Analyze the dataset and provide key findings.",
#     expected_output="A detailed analysis of the dataset.",
#     agent=data_analyst,
#     context=df.head().to_dict()
# )
#
# summary_task = Task(
#     description="Create a summary report based on the analysis.",
#     expected_output="A concise summary report.",
#     agent=summarizer,
#     context="The analysis results from the previous step."
# )
#
# # Create and run the crew
# crew = Crew(
#     agents=[data_analyst, summarizer],
#     tasks=[analysis_task, summary_task],
#     process=Process.sequential,
#     verbose=2
# )
#
# result = crew.kickoff()
# print("\nFinal Report:\n", result)
# ``` ```
# Analizza: - correttezza funzionale - presenza di bug logici - leggibilità e aderenza alle best practice - presenza di docstring o commenti
# Rispondi esclusivamente con una versione migliorata del codice.
#
#
#
# # Agent: Senior Code Reviewer
# ## Final Answer:
# ```python
# """
# CrewAI example: Exploratory Data Analysis and Summary Report
# ============================================================
#
# This script demonstrates how to use the `crewai` library to orchestrate
# two agents – a Data Analyst and a Summarizer – in a sequential workflow.
# It generates a synthetic dataset, runs an exploratory data analysis,
# and finally produces a concise summary report.
#
# The code follows best practices such as:
#
# * type‑annotated functions
# * proper logging instead of bare ``print`` statements
# * reproducible random data generation
# * clear separation of concerns
# * comprehensive docstrings
# """
#
# import logging
# import random
# from typing import Tuple
#
# import numpy as np
# import pandas as pd
# from crewai import Agent, Crew, Process, Task
#
# # --------------------------------------------------------------------------- #
# # Configuration
# # --------------------------------------------------------------------------- #
#
# # Reproducibility
# SEED = 42
# random.seed(SEED)
# np.random.seed(SEED)
#
# # Logging configuration
# logging.basicConfig(
#     level=logging.INFO,
#     format="%(asctime)s [%(levelname)s] %(message)s",
#     datefmt="%H:%M:%S",
# )
# logger = logging.getLogger(__name__)
#
#
# # --------------------------------------------------------------------------- #
# # Helper functions
# # --------------------------------------------------------------------------- #
# def create_dataset(n_samples: int = 10) -> pd.DataFrame:
#     """
#     Generate a synthetic dataset containing sales, profit and region.
#
#     Parameters
#     ----------
#     n_samples : int, default 10
#         Number of rows in the generated DataFrame.
#
#     Returns
#     -------
#     pd.DataFrame
#         DataFrame with columns ``Sales``, ``Profit`` and ``Region``.
#     """
#     logger.debug("Generating synthetic dataset with %d samples", n_samples)
#     data = {
#         "Sales": np.random.randint(50, 200, n_samples),
#         "Profit": np.random.uniform(5.0, 20.0, n_samples),
#         "Region": np.random.choice(["North", "South", "East", "West"], n_samples),
#     }
#     return pd.DataFrame(data)
#
#
# def create_agents() -> Tuple[Agent, Agent]:
#     """
#     Instantiate the two agents used in the crew.
#
#     Returns
#     -------
#     tuple[Agent, Agent]
#         The first element is the Data Analyst, the second is the Summarizer.
#     """
#     data_analyst = Agent(
#         role="Data Analyst",
#         goal="Perform exploratory data analysis on the dataset and generate insights.",
#         backstory="Experienced in statistical analysis and data visualization.",
#         verbose=True,
#         allow_delegation=False,
#     )
#
#     summarizer = Agent(
#         role="Summarizer",
#         goal="Summarize the insights from the Data Analyst into a concise report.",
#         backstory="Skilled in clear communication and report writing.",
#         verbose=True,
#         allow_delegation=False,
#     )
#     return data_analyst, summarizer
#
#
# def create_tasks(df: pd.DataFrame, analyst: Agent, summarizer: Agent) -> list[Task]:
#     """
#     Build the list of tasks for the crew.
#
#     Parameters
#     ----------
#     df : pd.DataFrame
#         The dataset to be analysed.
#     analyst : Agent
#         The agent that will perform the analysis.
#     summarizer : Agent
#         The agent that will produce the summary.
#
#     Returns
#     -------
#     list[Task]
#         Ordered list of tasks: analysis followed by summarisation.
#     """
#     # Convert the first few rows to a human‑readable string for the context
#     context_head = df.head().to_string(index=False)
#
#     analysis_task = Task(
#         description="Analyze the dataset and provide key findings.",
#         expected_output="A detailed analysis of the dataset.",
#         agent=analyst,
#         context=context_head,
#     )
#
#     summary_task = Task(
#         description="Create a summary report based on the analysis.",
#         expected_output="A concise summary report.",
#         agent=summarizer,
#         context="The analysis results from the previous step.",
#     )
#
#     return [analysis_task, summary_task]
#
#
# def run_crew(df: pd.DataFrame, tasks: list[Task]) -> str:
#     """
#     Execute the crew workflow and return the final report.
#
#     Parameters
#     ----------
#     df : pd.DataFrame
#         Dataset (unused here but kept for potential future use).
#     tasks : list[Task]
#         Ordered list of tasks to execute.
#
#     Returns
#     -------
#     str
#         Final report produced by the summariser.
#     """
#     agents = [task.agent for task in tasks]
#     crew = Crew(
#         agents=agents,
#         tasks=tasks,
#         process=Process.sequential,
#         verbose=2,
#     )
#
#     logger.info("Starting crew kickoff")
#     result = crew.kickoff()
#     logger.info("Crew execution finished")
#     return result
#
#
# # --------------------------------------------------------------------------- #
# # Main entry point
# # --------------------------------------------------------------------------- #
# def main() -> None:
#     """
#     Orchestrate the end‑to‑end workflow:
#     1. Create dataset
#     2. Instantiate agents
#     3. Build tasks
#     4. Run crew
#     5. Print final report
#     """
#     df = create_dataset()
#     analyst, summarizer = create_agents()
#     tasks = create_tasks(df, analyst, summarizer)
#
#     try:
#         final_report = run_crew(df, tasks)
#     except Exception as exc:  # pragma: no cover
#         logger.exception("Crew execution failed: %s", exc)
#         raise
#
#     print("\nFinal Report:\n", final_report)
#
#
# if __name__ == "__main__":  # pragma: no cover
#     main()
# ```
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# └── ✅ Completed: upgrade_code
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── 🔄 Running: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── 🔄 Running: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── 🔄 Running: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     📝 Scrittura sezione Motivazioni                                                                ]8;id=219212;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=236592;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#53\53]8;;\
# # Agent: Technical Writer
# ## Task: Scrivi la sezione 'Motivazioni' per l’articolo intitolato 'CrewAI un framework per i tuoi agenti AI' e avente abstract 'Il framework CrewAI è stato concepito per facilitare la progettazione, l’implementazione e la gestione di sistemi multi‑agente intelligenti. Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni elevate. In questo articolo presentiamo i principi fondamentali del framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto decisionale alla gestione autonoma di processi complessi. Vengono inoltre analizzati casi d’uso reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale collaborativa.'. Mantieni coerenza con le sezioni precedenti, riassunte in: {'Introduzione': 'The introduction addresses the limitations of current AI solutions which often rely on monolithic models and are insufficient for handling complex scenarios like large data analysis or autonomous industrial process management. To address this, CrewAI is introduced as an innovative framework aimed at facilitating the design, implementation, and management of multi-agent intelligent systems with a modular architecture and intuitive programming interface. It features dynamic composition, clearly defined roles, sophisticated planning and coordination mechanisms, and robust security and auditing capabilities. The article is structured to cover CrewAI\'s foundational principles, practical custom solution-building, and real-world use cases alongside future prospects. Ultimately, CrewAI alleviates the need for developers to manually manage agent interactions by orchestrating, monitoring, and optimizing the entire ecosystem, enabling a focus on specific AI competencies.\n\nNow, let me provide a Python code snippet demonstrating how to create a crew with two agents ("DataAnalyst" and "Summarizer"), assign them a data analysis task, and generate a summary report:\n\n```python\n# [START] Code snippet for creating a CrewAI setup\n\nfrom crewai import Crew, Agent, Task\n\n# Initialize the Crew\ncrew = Crew()\n\n# Define the roles with specific agents\ndata_analyst = Agent(name="DataAnalyst", role="analyze_data")\nsummarizer = Agent(name="Summarizer", role="generate_summary")\n\n# Add agents to the Crew\ncrew.add_agent(data_analyst)\ncrew.add_agent(summarizer)\n\n# Define a task for data analysis and summarization\nclass DataAnalysisTask(Task):\n    def __init__(self, dataset):\n        self.dataset = dataset\n    \n    async def perform(self, crew: "Crew"):\n        # Perform data analysis\n        analysis_result = await self.execute_for(data_analyst)\n        \n        # Generate summary based on the analysis\n        summary_report = await self.execute_for(summarizer, input=analysis_result)\n        \n        return summary_report\n\n# Simulated dataset\ndataset = ["data_point_1", "data_point_2", "data_point_3"]\n\n# Create and assign the task to the Crew\ntask = DataAnalysisTask(dataset=dataset)\nreport = crew.run(task)\n\n# Print the final report output\nprint("Summary Report:", report)\n\n# [END]\n```\n\nThis code snippet demonstrates initializing a Crew with two agents, assigning them tasks for data analysis and summarization, and printing out the resulting summary report.'}
# Se ritieni utile includere codice Python, aggiungi in fondo una riga che inizia con: [CODICE_RICHIESTO][START] istruzione dettagliata in linguaggio naturale. [END]
#
#
#
# # Agent: Technical Writer
# ## Final Answer:
# **Motivazioni**
#
# Le soluzioni AI attualmente diffuse si basano spesso su modelli monolitici, capaci di eseguire un unico compito con un alto grado di accuratezza. Questa architettura, sebbene efficace per applicazioni semplici, presenta una serie di limitazioni quando si affrontano scenari complessi e dinamici:
#
# 1. **Scalabilità limitata** – Un singolo modello deve gestire tutti i requisiti, dalla raccolta dati all’analisi, dalla generazione di raccomandazioni alla gestione di processi in tempo reale. Man mano che le dimensioni del problema aumentano, le prestazioni e la latenza peggiorano in modo esponenziale.
#
# 2. **Flessibilità ridotta** – L’aggiunta di nuove funzionalità richiede il retraining completo del modello, un processo costoso sia in termini di tempo che di risorse computazionali. Ciò impedisce l’adattamento rapido alle mutevoli esigenze del business.
#
# 3. **Manutenibilità complessa** – La manutenibilità di un modello monolitico è un problema, poiché qualsiasi modifica può avere effetti collaterali imprevedibili su parti non correlate del sistema. Il debugging diventa un’impresa ardua.
#
# 4. **Sicurezza e auditabilità** – In un contesto in cui i dati sono sensibili e le decisioni hanno impatti reali, è fondamentale poter tracciare l’origine delle azioni e garantire che ogni componente operi entro i limiti di sicurezza stabiliti. Un modello monolitico offre una visibilità limitata su questi aspetti.
#
# CrewAI nasce per superare queste criticità introducendo un paradigma multi‑agente in cui ogni agente è specializzato in un compito specifico e opera all’interno di un’architettura modulare. Le principali motivazioni alla base di questo approccio sono:
#
# - **Composizione dinamica** – Gli agenti possono essere aggiunti, rimossi o sostituiti in tempo reale, consentendo al sistema di evolvere con le esigenze del dominio senza dover ristrutturare l’intero modello.
#
# - **Specializzazione e cooperazione** – Ogni agente è dotato di una “ruolo” ben definito (es. analisi dati, generazione di report, gestione della sicurezza). Grazie a meccanismi di pianificazione e coordinamento avanzati, gli agenti collaborano per raggiungere obiettivi complessi, riducendo la complessità di progettazione.
#
# - **Modularità e riusabilità** – I componenti possono essere riutilizzati in diversi contesti, facilitando la creazione di soluzioni personalizzate con tempi di sviluppo ridotti.
#
# - **Sicurezza e auditabilità** – Ogni agente è isolato e controllato, con log dettagliati delle sue azioni. Ciò facilita la verifica della conformità normativa e l’identificazione rapida di anomalie.
#
# - **Performance e scalabilità** – L’esecuzione parallela di più agenti su infrastrutture distribuite permette di sfruttare appieno le risorse computazionali, mantenendo tempi di risposta bassi anche in scenari ad alto carico.
#
# - **Facilità di integrazione** – L’interfaccia di programmazione intuitiva di CrewAI permette agli sviluppatori di concentrarsi sulle competenze specifiche dei singoli agenti, delegando all’framework la gestione dell’orchestrazione, del monitoraggio e dell’ottimizzazione.
#
# In sintesi, CrewAI è stato concepito per trasformare la progettazione di sistemi AI da un modello monolitico e rigidamente definito a un ecosistema flessibile, scalabile e sicuro, in cui gli agenti intelligenti collaborano in modo coordinato per affrontare compiti complessi e dinamici. Questa filosofia risponde direttamente alle esigenze emergenti di business che richiedono soluzioni AI agili, adattabili e altamente affidabili.
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── 🔄 Running: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── 🔄 Running: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── 🔄 Running: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── 🔄 Running: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     📝 Scrittura sezione Architettura                                                               ]8;id=897652;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=545668;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#53\53]8;;\
# # Agent: Technical Writer
# ## Task: Scrivi la sezione 'Architettura' per l’articolo intitolato 'CrewAI un framework per i tuoi agenti AI' e avente abstract 'Il framework CrewAI è stato concepito per facilitare la progettazione, l’implementazione e la gestione di sistemi multi‑agente intelligenti. Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni elevate. In questo articolo presentiamo i principi fondamentali del framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto decisionale alla gestione autonoma di processi complessi. Vengono inoltre analizzati casi d’uso reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale collaborativa.'. Mantieni coerenza con le sezioni precedenti, riassunte in: {'Introduzione': 'The introduction addresses the limitations of current AI solutions which often rely on monolithic models and are insufficient for handling complex scenarios like large data analysis or autonomous industrial process management. To address this, CrewAI is introduced as an innovative framework aimed at facilitating the design, implementation, and management of multi-agent intelligent systems with a modular architecture and intuitive programming interface. It features dynamic composition, clearly defined roles, sophisticated planning and coordination mechanisms, and robust security and auditing capabilities. The article is structured to cover CrewAI\'s foundational principles, practical custom solution-building, and real-world use cases alongside future prospects. Ultimately, CrewAI alleviates the need for developers to manually manage agent interactions by orchestrating, monitoring, and optimizing the entire ecosystem, enabling a focus on specific AI competencies.\n\nNow, let me provide a Python code snippet demonstrating how to create a crew with two agents ("DataAnalyst" and "Summarizer"), assign them a data analysis task, and generate a summary report:\n\n```python\n# [START] Code snippet for creating a CrewAI setup\n\nfrom crewai import Crew, Agent, Task\n\n# Initialize the Crew\ncrew = Crew()\n\n# Define the roles with specific agents\ndata_analyst = Agent(name="DataAnalyst", role="analyze_data")\nsummarizer = Agent(name="Summarizer", role="generate_summary")\n\n# Add agents to the Crew\ncrew.add_agent(data_analyst)\ncrew.add_agent(summarizer)\n\n# Define a task for data analysis and summarization\nclass DataAnalysisTask(Task):\n    def __init__(self, dataset):\n        self.dataset = dataset\n    \n    async def perform(self, crew: "Crew"):\n        # Perform data analysis\n        analysis_result = await self.execute_for(data_analyst)\n        \n        # Generate summary based on the analysis\n        summary_report = await self.execute_for(summarizer, input=analysis_result)\n        \n        return summary_report\n\n# Simulated dataset\ndataset = ["data_point_1", "data_point_2", "data_point_3"]\n\n# Create and assign the task to the Crew\ntask = DataAnalysisTask(dataset=dataset)\nreport = crew.run(task)\n\n# Print the final report output\nprint("Summary Report:", report)\n\n# [END]\n```\n\nThis code snippet demonstrates initializing a Crew with two agents, assigning them tasks for data analysis and summarization, and printing out the resulting summary report.', 'Motivazioni': 'The "Motivazioni" section outlines the limitations of current AI systems that rely on monolithic models: limited scalability, reduced flexibility, complex maintenance, and security challenges. CrewAI addresses these issues by introducing a multi-agent architecture that allows dynamic composition, specialization and cooperation among agents with defined roles, modularity and reusability, enhanced security and auditability through isolated operation and detailed logging, performance and scalability via parallel execution on di ...
# Se ritieni utile includere codice Python, aggiungi in fondo una riga che inizia con: [CODICE_RICHIESTO][START] istruzione dettagliata in linguaggio naturale. [END]
#
#
#
# # Agent: Technical Writer
# ## Final Answer:
# **Architettura**
#
# CrewAI è stato concepito come un framework modulare, ispirato ai principi dei micro‑servizi e dell’event‑driven architecture. L’architettura è suddivisa in tre livelli principali – *Core*, *Application* e *Integration* – ognuno dei quali è composto da componenti che possono essere scambiati, estesi o configurati in base alle esigenze specifiche del progetto.
#
# ---
#
# ### 1. Core – Il motore intelligente
#
# | Componente | Funzione | Interfacce principali |
# |------------|----------|-----------------------|
# | **Crew** | Gestisce l’intera orchestrazione, mantiene lo stato degli agenti e coordina l’esecuzione delle task. | `add_agent`, `add_task`, `run`, `monitor` |
# | **Agent** | Rappresenta un’entità autonoma con un ruolo definito (es. *DataAnalyst*, *Summarizer*). | `role`, `tools`, `memory` |
# | **Task** | Un’unità di lavoro che può essere assegnata a uno o più agenti. | `perform`, `dependencies`, `timeout` |
# | **Planner** | Algoritmo che decide la sequenza di esecuzione delle task, ottimizzando risorse e tempi. | `plan`, `schedule` |
# | **Coordinator** | Responsabile della sincronizzazione e della comunicazione tra agenti, gestendo lock, buffer e queue. | `send_message`, `receive_message` |
#
# Questi componenti interagiscono tramite un bus di eventi interno: ogni *Agent* emette eventi (es. *TaskStarted*, *TaskCompleted*) che vengono consumati dal *Coordinator* e, se necessario, da sistemi esterni di monitoring.
#
# ---
#
# ### 2. Application – Personalizzazione e estensibilità
#
# CrewAI è pensato per essere esteso senza modificare il core. Gli sviluppatori possono:
#
# | Tipo di estensione | Come fare |
# |--------------------|-----------|
# | **Nuovo Planner** | Implementare l’interfaccia `Planner` e registrarlo nella configurazione di *Crew*. |
# | **Nuovo Agent** | Derivare da `Agent`, definire `role`, `tools` e override di `perform`. |
# | **Custom Tool** | Creare un wrapper che espone un’API esterna (es. REST, gRPC) e registrarlo con l’agente. |
# | **Plugin di sicurezza** | Integrare un middleware di autorizzazione che filtra i messaggi in base al ruolo. |
#
# Il pattern *Dependency Injection* è usato per iniettare componenti esterni (logger, database, service di machine‑learning) garantendo che il core rimanga agnostico rispetto all’implementazione concreta.
#
# ---
#
# ### 3. Integration – Connettività e osservabilità
#
# | Strumento | Scopo |
# |-----------|-------|
# | **API REST/GraphQL** | Permette di creare, modificare e monitorare crew da applicazioni front‑end o servizi di orchestrazione. |
# ...
#         "Use the 'analyze_data' tool to compute statistics and then the 'summarize' tool to create a concise summary."
#     ),
#     expected_output="A concise summary of the data analysis.",
#     agent=data_analyst,
# )
#
# # -------------------- CRAFT CRED --------------------
# crew = Crew(
#     agents=[data_analyst, summarizer],
#     tasks=[analysis_task],
#     verbose=2,
# )
#
# # -------------------- SAMPLE DATA --------------------
# def create_sample_data(csv_path: str):
#     df = pd.DataFrame({
#         "id": range(1, 11),
#         "value": [10, 15, 20, 25, 30, 35, 40, 45, 50, 55],
#         "category": ["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"],
#     })
#     df.to_csv(csv_path, index=False)
#     logger.info(f"Sample data created at {csv_path}")
#
#
# # -------------------- MAIN --------------------
# async def main():
#     # Create sample data
#     csv_path = "sample_data.csv"
#     create_sample_data(csv_path)
#
#     # Start WebSocket server
#     ws_server = await start_ws_server()
#
#     # Run the crew
#     await crew.kickoff()
#
#     # Give some time for final messages to be sent
#     await asyncio.sleep(1)
#
#     # Close WebSocket server
#     ws_server.close()
#     await ws_server.wait_closed()
#     logger.info("WebSocket server closed")
#
#
# if __name__ == "__main__":
#     asyncio.run(main())
# ``` ```
# Analizza: - correttezza funzionale - presenza di bug logici - leggibilità e aderenza alle best practice - presenza di docstring o commenti
# Rispondi esclusivamente con una versione migliorata del codice.
#
#
#
# # Agent: Senior Code Reviewer
# ## Final Answer:
# ```python
# """Main entry point for the data‑analysis crew.
#
# The script demonstrates how to orchestrate a crew of agents that
# perform data analysis and summarisation while broadcasting progress
# through a WebSocket server.  The code follows best practices for
# readability, maintainability, and security.
# """
#
# import json
# import logging
# import os
# from dataclasses import dataclass, field
# from typing import Dict, Set
#
# import pandas as pd
# import websockets
# from crewai import Agent, Task, Crew
# from crewai_tools import BaseTool
#
# # --------------------------------------------------------------------------- #
# # Configuration
# # --------------------------------------------------------------------------- #
#
# # The OpenAI API key must be supplied via the environment variable.
# OPENAI_API_KEY: str | None = os.getenv("OPENAI_API_KEY")
# if not OPENAI_API_KEY:
#     raise RuntimeError(
#         "The environment variable OPENAI_API_KEY must be set before running the script."
#     )
#
# WS_HOST: str = "localhost"
# WS_PORT: int = 8765
# WS_PATH: str = "/"
#
# # --------------------------------------------------------------------------- #
# # Logging
# # --------------------------------------------------------------------------- #
#
# logging.basicConfig(
#     level=logging.INFO,
#     format="%(asctime)s %(levelname)s %(name)s: %(message)s",
#     handlers=[logging.StreamHandler()],
# )
# logger = logging.getLogger(__name__)
#
# # --------------------------------------------------------------------------- #
# # WebSocket server
# # --------------------------------------------------------------------------- #
#
# class WebSocketManager:
#     """Keeps track of connected WebSocket clients and broadcasts messages."""
#
#     def __init__(self) -> None:
#         self._connected_clients: Set[websockets.WebSocketServerProtocol] = set()
#         self._lock = asyncio.Lock()
#
#     async def register(self, websocket: websockets.WebSocketServerProtocol) -> None:
#         async with self._lock:
#             self._connected_clients.add(websocket)
#             logger.info(
#                 "WebSocket client connected. Total clients: %d",
#                 len(self._connected_clients),
#             )
#
#     async def unregister(self, websocket: websockets.WebSocketServerProtocol) -> None:
#         async with self._lock:
#             self._connected_clients.discard(websocket)
#             logger.info(
#                 "WebSocket client disconnected. Total clients: %d",
#                 len(self._connected_clients),
#             )
#
#     async def broadcast(self, message: str) -> None:
#         """Send *message* to all currently connected clients."""
#         async with self._lock:
#             if not self._connected_clients:
#                 return
#
#             coros = [client.send(message) for client in self._connected_clients]
#             results = await asyncio.gather(*coros, return_exceptions=True)
#
#             for client, result in zip(self._connected_clients, results):
#                 if isinstance(result, Exception):
#                     logger.error(
#                         "Error sending message to %s: %s",
#                         client.remote_address,
#                         result,
#                     )
#
#
# ws_manager = WebSocketManager()
#
# async def websocket_handler(
#     websocket: websockets.WebSocketServerProtocol, path: str
# ) -> None:
#     await ws_manager.register(websocket)
#     try:
#         await websocket.wait_closed()
#     finally:
#         await ws_manager.unregister(websocket)
#
#
# async def start_ws_server() -> websockets.server.Serve:
#     """Starts the WebSocket server and returns the server instance."""
#     server = await websockets.serve(
#         websocket_handler, WS_HOST, WS_PORT, path=WS_PATH
#     )
#     logger.info(
#         "WebSocket server started on ws://%s:%d%s", WS_HOST, WS_PORT, WS_PATH
#     )
#     return server
#
#
# # --------------------------------------------------------------------------- #
# # Shared state
# # --------------------------------------------------------------------------- #
#
# @dataclass
# class SharedState:
#     """Container for data that needs to be shared between tools."""
#
#     analysis: Dict | None = None
#
#
# shared_state = SharedState()
#
#
# # --------------------------------------------------------------------------- #
# # Custom tools
# # --------------------------------------------------------------------------- #
#
# class AnalyzeDataTool(BaseTool):
#     """Tool that reads a CSV file and returns basic statistics."""
#
#     name = "analyze_data"
#     description = "Analyze a CSV file and return basic statistics."
#
#     def _run(self, file_path: str | None = None) -> str:
#         """Execute the analysis.
#
#         Args:
#             file_path: Path to the CSV file. If omitted, uses
#                 'sample_data.csv' in the current working directory.
#
#         Returns:
#             A message containing the analysis statistics.
#         """
#         target_file = file_path or "sample_data.csv"
#         logger.info("Analyzing data from %s", target_file)
#
#         try:
#             df = pd.read_csv(target_file)
#         except FileNotFoundError as exc:
#             error_msg = f"File not found: {target_file}"
#             logger.exception(error_msg)
#             raise RuntimeError(error_msg) from exc
#         except Exception as exc:
#             error_msg = f"Error reading {target_file}: {exc}"
#             logger.exception(error_msg)
#             raise RuntimeError(error_msg) from exc
#
#         stats_json = df.describe(include="all").to_json()
#         shared_state.analysis = json.loads(stats_json)
#
#         message = f"Data analysis completed. Stats: {stats_json}"
#         asyncio.create_task(ws_manager.broadcast(message))
#         return message
#
#
# class SummarizeTool(BaseTool):
#     """Tool that creates a concise summary of the analysis results."""
#
#     name = "summarize"
#     description = "Summarize the analysis results."
#
#     def _run(self) -> str:
#         logger.info("Summarizing analysis results")
#         analysis = shared_state.analysis
#         if not analysis:
#             return "No analysis data available."
#
#         summary = f"Summary of analysis: {json.dumps(analysis, indent=2)}"
#         message = f"Summarization completed. {summary}"
#         asyncio.create_task(ws_manager.broadcast(message))
#         return message
#
#
# # --------------------------------------------------------------------------- #
# # Agents
# # --------------------------------------------------------------------------- #
#
# data_analyst = Agent(
#     role="Data Analyst",
#     goal="Perform data analysis and provide insights.",
#     backstory=(
#         "You are a seasoned data analyst with a knack for turning raw data "
#         "into actionable insights."
#     ),
#     verbose=True,
#     tools=[AnalyzeDataTool()],
# )
#
# summarizer = Agent(
#     role="Summarizer",
#     goal="Summarize the analysis results for stakeholders.",
#     backstory=(
#         "You specialize in communicating complex data insights in simple terms."
#     ),
#     verbose=True,
#     tools=[SummarizeTool()],
# )
#
# # --------------------------------------------------------------------------- #
# # Task
# # --------------------------------------------------------------------------- #
#
# analysis_task = Task(
#     description=(
#         "Analyze the dataset located at 'sample_data.csv' and produce a summary. "
#         "Use the 'analyze_data' tool to compute statistics and then the 'summarize' tool "
#         "to create a concise summary."
#     ),
#     expected_output="A concise summary of the data analysis.",
#     agent=data_analyst,
# )
#
# # --------------------------------------------------------------------------- #
# # Crew
# # --------------------------------------------------------------------------- #
#
# crew = Crew(
#     agents=[data_analyst, summarizer],
#     tasks=[analysis_task],
#     verbose=2,
# )
#
# # --------------------------------------------------------------------------- #
# # Sample data generation
# # --------------------------------------------------------------------------- #
#
# def create_sample_data(csv_path: str) -> None:
#     """Create a small CSV file used for demonstration."""
#     df = pd.DataFrame(
#         {
#             "id": range(1, 11),
#             "value": [10, 15, 20, 25, 30, 35, 40, 45, 50, 55],
#             "category": ["A", "B", "A", "B", "A", "B", "A", "B", "A", "B"],
#         }
#     )
#     df.to_csv(csv_path, index=False)
#     logger.info("Sample data created at %s", csv_path)
#
#
# # --------------------------------------------------------------------------- #
# # Main entry point
# # --------------------------------------------------------------------------- #
#
# async def main() -> None:
#     """Run the whole workflow: create data, start server, kick off crew."""
#     csv_path = "sample_data.csv"
#     create_sample_data(csv_path)
#
#     # Start WebSocket server
#     ws_server = await start_ws_server()
#
#     # Kick off the crew
#     await crew.kickoff()
#
#     # Allow some time for all messages to be sent
#     await asyncio.sleep(1)
#
#     # Close the WebSocket server gracefully
#     ws_server.close()
#     await ws_server.wait_closed()
#     logger.info("WebSocket server closed")
#
#
# if __name__ == "__main__":
#     asyncio.run(main())
# ```
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── 🔄 Running: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── 🔄 Running: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# └── ✅ Completed: loop_till_last_section
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# ├── ✅ Completed: loop_till_last_section
# └── 🔄 Running: conclude
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# INFO     🏁 Flow terminato con successo.                                                                ]8;id=449973;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=160152;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#121\121]8;;\
# INFO     📊 Riepilogo log: {'log_lines': 30, 'log_levels': {'INFO': 30}, 'level_ratio': {'INFO':        ]8;id=617754;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py\flow.py]8;;\:]8;id=982680;file:///Users/alessandro.cimarelli/Desktop/PERSONALGITHUB/blogwriter/crews/writing/flow.py#131\131]8;;\
#          100.0}, 'transitions': {}, 'duration_seconds': 1302.0, 'avg_interval_seconds':
#          44.89655172413793, 'first_entry': '2025-09-05 16:49:02', 'last_entry': '2025-09-05 17:10:44',
#          'top_messages': [('2025-09-05 16:49:02 | INFO     | WritingArticleFlow | 🚀 Avvio asincrono
#          del flow WritingArticleFlow', 1), ('2025-09-05 16:49:02 | INFO     | WritingArticleFlow | 🚀
#          Attivo la crew per la generazione sezioni articolo...', 1), ('2025-09-05 16:49:02 | INFO     |
#          WritingArticleFlow | 📝 Scrittura sezione Introduzione', 1), ('2025-09-05 16:50:05 | INFO
#          | WritingArticleFlow | 🚀 Attivo la crew per la generazione del codice interno alla sezione
#          Introduzione', 1), ('2025-09-05 16:50:05 | INFO     | WritingArticleFlow | 📝 Generazione
#          codice...', 1)]}
# 🌊 Flow: WritingArticleFlow
#     ID: ae9c9371-cb01-4860-8796-9b3d97813cb0
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# ├── ✅ Completed: loop_till_last_section
# └── ✅ Completed: conclude
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Flow Finished: WritingArticleFlow
# ├── Flow Method Step
# ├── ✅ Completed: start_article
# ├── ✅ Completed: check_written_sections
# ├── ✅ Completed: write_section
# ├── ✅ Completed: code_generation_node
# ├── ✅ Completed: write_code
# ├── ✅ Completed: upgrade_code
# ├── ✅ Completed: loop_till_last_section
# └── ✅ Completed: conclude

# %%
crew2.flow.plot(filename='WritingFlow')
# Out:
# Plot saved as WritingFlow.html

# %%
l_str= 150

pprint.pprint('*Title', width=l_str)
pprint.pprint(state2.__dict__['title'], width=l_str)
pprint.pprint('', width=l_str)

pprint.pprint('*Abstract', width=l_str)
pprint.pprint(state2.__dict__['abstract'], width=l_str)
pprint.pprint('', width=l_str)

pprint.pprint('*Structure', width=l_str)
pprint.pprint(state2.__dict__['structure'], width=l_str)
pprint.pprint('', width=l_str)

for k in crew2.flow.state.__dict__['structure']:
    pprint.pprint(k, width=l_str)
    pprint.pprint(crew2.flow.state.__dict__['paragraphs'][k], width=l_str)
    pprint.pprint('-'*l_str, width=l_str)
    pprint.pprint('', width=l_str)
# Out:
# '*Title'
# 'CrewAI un framework per i tuoi agenti AI'
# ''
# '*Abstract'
# ('Il framework CrewAI è stato concepito per facilitare la progettazione, l’implementazione e la gestione di sistemi multi‑agente intelligenti. '
#  'Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI permette di orchestrare in modo semplice e scalabile '
#  'l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni elevate. In questo articolo presentiamo i principi '
#  'fondamentali del framework, illustrando come sfruttarlo per costruire soluzioni personalizzate, dal supporto decisionale alla gestione autonoma di '
#  'processi complessi. Vengono inoltre analizzati casi d’uso reali e le potenzialità future di CrewAI nel contesto dell’intelligenza artificiale '
#  'collaborativa.')
# ''
# '*Structure'
# ['Introduzione',
#  'Motivazioni',
#  'Architettura',
#  'Interfaccia di programmazione',
#  'Principi fondamentali',
#  'Uso pratico',
#  "Casi d'uso",
#  'Potenzialità future',
#  'Conclusioni']
# ''
# 'Introduzione'
# ('**Introduzione**\n'
#  '\n'
#  'L’intelligenza artificiale ha compiuto passi da gigante negli ultimi anni, ma la maggior parte delle soluzioni commerciali e di ricerca rimane '
#  'ancora focalizzata su singoli modelli monolitici. In scenari complessi—come l’analisi di grandi volumi di dati, la generazione di contenuti '
#  'creativi o la gestione autonoma di processi industriali—una singola intelligenza spesso non è sufficiente: serve un ecosistema di agenti '
#  'specializzati che collaborano in modo coerente e scalabile.  \n'
#  '\n'
#  'CrewAI nasce proprio per colmare questa lacuna. Il framework è stato concepito con l’obiettivo di **facilitare la progettazione, l’implementazione '
#  'e la gestione di sistemi multi‑agente intelligenti**. Grazie a un’architettura modulare e a un’interfaccia di programmazione intuitiva, CrewAI '
#  'permette di orchestrare in modo semplice e scalabile l’interazione tra agenti AI con compiti diversi, garantendo coerenza, sicurezza e prestazioni '
#  'elevate.  \n'
#  '\n'
#  'Tra le caratteristiche distintive di CrewAI troviamo:\n'
#  '\n'
#  '* **Composizione dinamica**: i team di agenti possono essere creati, modificati o distrutti in tempo reale, adattandosi alle mutevoli esigenze del '
#  'task.\n'
#  '* **Ruoli e responsabilità chiaramente definiti**: ogni agente è dotato di un profilo di competenze, consentendo una distribuzione ottimale del '
#  'lavoro e riducendo i conflitti di sovrapposizione.\n'
#  '* **Pianificazione e coordinamento**: il motore di orchestrazione gestisce la sequenza delle attività, le dipendenze e la sincronizzazione tra '
#  'agenti, senza richiedere agli sviluppatori di scrivere logica complessa di scheduling.\n'
#  '* **Sicurezza e audit**: tutti i messaggi tra agenti sono tracciati, e i permessi possono essere configurati a livello di ruolo, garantendo '
#  'trasparenza e conformità a normative specifiche.\n'
#  '\n'
#  'L’articolo che segue si articola in tre parti principali:\n'
#  '\n'
#  '1. **Principi fondamentali di CrewAI** – descrizione dell’architettura, dei componenti chiave (Crew, Agent, Task, Scheduler) e delle best‑practice '
#  'per la definizione dei ruoli.\n'
#  '2. **Costruire soluzioni personalizzate** – esempi pratici, dalla creazione di un team per il supporto decisionale alla gestione autonoma di un '
#  'workflow complesso, con focus su integrazioni esterne (API, database, sistemi legacy).\n'
#  '3. **Casi d’uso reali e prospettive future** – analisi di progetti pilota in ambito finanziario, sanitario e industriale, oltre a una panoramica '
#  'delle potenzialità emergenti (integrazione con modelli di linguaggio di nuova generazione, apprendimento continuo, evoluzione autonoma dei '
#  'ruoli).\n'
#  '\n'
#  'Con CrewAI, gli sviluppatori non devono più preoccuparsi di gestire manualmente le interazioni tra agenti; il framework si occupa di orchestrare, '
#  'monitorare e ottimizzare l’intero ecosistema, consentendo di concentrarsi sul valore aggiunto delle singole competenze AI.  \n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Scrivi un frammento di codice Python che dimostri come creare un crew con due agenti (un “DataAnalyst” e un '
#  '“Summarizer”), assegnare loro un task di analisi di un dataset e generare un report riassuntivo. Assicurati di includere l’inizializzazione del '
#  'crew, la definizione dei ruoli, l’invio del task e la stampa dell’output finale. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Motivazioni'
# ('**Motivazioni**\n'
#  '\n'
#  'Le soluzioni AI attualmente diffuse si basano spesso su modelli monolitici, capaci di eseguire un unico compito con un alto grado di accuratezza. '
#  'Questa architettura, sebbene efficace per applicazioni semplici, presenta una serie di limitazioni quando si affrontano scenari complessi e '
#  'dinamici:\n'
#  '\n'
#  '1. **Scalabilità limitata** – Un singolo modello deve gestire tutti i requisiti, dalla raccolta dati all’analisi, dalla generazione di '
#  'raccomandazioni alla gestione di processi in tempo reale. Man mano che le dimensioni del problema aumentano, le prestazioni e la latenza '
#  'peggiorano in modo esponenziale.\n'
#  '\n'
#  '2. **Flessibilità ridotta** – L’aggiunta di nuove funzionalità richiede il retraining completo del modello, un processo costoso sia in termini di '
#  'tempo che di risorse computazionali. Ciò impedisce l’adattamento rapido alle mutevoli esigenze del business.\n'
#  '\n'
#  '3. **Manutenibilità complessa** – La manutenibilità di un modello monolitico è un problema, poiché qualsiasi modifica può avere effetti '
#  'collaterali imprevedibili su parti non correlate del sistema. Il debugging diventa un’impresa ardua.\n'
#  '\n'
#  '4. **Sicurezza e auditabilità** – In un contesto in cui i dati sono sensibili e le decisioni hanno impatti reali, è fondamentale poter tracciare '
#  'l’origine delle azioni e garantire che ogni componente operi entro i limiti di sicurezza stabiliti. Un modello monolitico offre una visibilità '
#  'limitata su questi aspetti.\n'
#  '\n'
#  'CrewAI nasce per superare queste criticità introducendo un paradigma multi‑agente in cui ogni agente è specializzato in un compito specifico e '
#  'opera all’interno di un’architettura modulare. Le principali motivazioni alla base di questo approccio sono:\n'
#  '\n'
#  '- **Composizione dinamica** – Gli agenti possono essere aggiunti, rimossi o sostituiti in tempo reale, consentendo al sistema di evolvere con le '
#  'esigenze del dominio senza dover ristrutturare l’intero modello.\n'
#  '\n'
#  '- **Specializzazione e cooperazione** – Ogni agente è dotato di una “ruolo” ben definito (es. analisi dati, generazione di report, gestione della '
#  'sicurezza). Grazie a meccanismi di pianificazione e coordinamento avanzati, gli agenti collaborano per raggiungere obiettivi complessi, riducendo '
#  'la complessità di progettazione.\n'
#  '\n'
#  '- **Modularità e riusabilità** – I componenti possono essere riutilizzati in diversi contesti, facilitando la creazione di soluzioni '
#  'personalizzate con tempi di sviluppo ridotti.\n'
#  '\n'
#  '- **Sicurezza e auditabilità** – Ogni agente è isolato e controllato, con log dettagliati delle sue azioni. Ciò facilita la verifica della '
#  'conformità normativa e l’identificazione rapida di anomalie.\n'
#  '\n'
#  '- **Performance e scalabilità** – L’esecuzione parallela di più agenti su infrastrutture distribuite permette di sfruttare appieno le risorse '
#  'computazionali, mantenendo tempi di risposta bassi anche in scenari ad alto carico.\n'
#  '\n'
#  '- **Facilità di integrazione** – L’interfaccia di programmazione intuitiva di CrewAI permette agli sviluppatori di concentrarsi sulle competenze '
#  'specifiche dei singoli agenti, delegando all’framework la gestione dell’orchestrazione, del monitoraggio e dell’ottimizzazione.\n'
#  '\n'
#  'In sintesi, CrewAI è stato concepito per trasformare la progettazione di sistemi AI da un modello monolitico e rigidamente definito a un '
#  'ecosistema flessibile, scalabile e sicuro, in cui gli agenti intelligenti collaborano in modo coordinato per affrontare compiti complessi e '
#  'dinamici. Questa filosofia risponde direttamente alle esigenze emergenti di business che richiedono soluzioni AI agili, adattabili e altamente '
#  'affidabili.')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Architettura'
# ('**Architettura**\n'
#  '\n'
#  'CrewAI è stato concepito come un framework modulare, ispirato ai principi dei micro‑servizi e dell’event‑driven architecture. L’architettura è '
#  'suddivisa in tre livelli principali – *Core*, *Application* e *Integration* – ognuno dei quali è composto da componenti che possono essere '
#  'scambiati, estesi o configurati in base alle esigenze specifiche del progetto.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 1. Core – Il motore intelligente\n'
#  '\n'
#  '| Componente | Funzione | Interfacce principali |\n'
#  '|------------|----------|-----------------------|\n'
#  '| **Crew** | Gestisce l’intera orchestrazione, mantiene lo stato degli agenti e coordina l’esecuzione delle task. | `add_agent`, `add_task`, '
#  '`run`, `monitor` |\n'
#  '| **Agent** | Rappresenta un’entità autonoma con un ruolo definito (es. *DataAnalyst*, *Summarizer*). | `role`, `tools`, `memory` |\n'
#  '| **Task** | Un’unità di lavoro che può essere assegnata a uno o più agenti. | `perform`, `dependencies`, `timeout` |\n'
#  '| **Planner** | Algoritmo che decide la sequenza di esecuzione delle task, ottimizzando risorse e tempi. | `plan`, `schedule` |\n'
#  '| **Coordinator** | Responsabile della sincronizzazione e della comunicazione tra agenti, gestendo lock, buffer e queue. | `send_message`, '
#  '`receive_message` |\n'
#  '\n'
#  'Questi componenti interagiscono tramite un bus di eventi interno: ogni *Agent* emette eventi (es. *TaskStarted*, *TaskCompleted*) che vengono '
#  'consumati dal *Coordinator* e, se necessario, da sistemi esterni di monitoring.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 2. Application – Personalizzazione e estensibilità\n'
#  '\n'
#  'CrewAI è pensato per essere esteso senza modificare il core. Gli sviluppatori possono:\n'
#  '\n'
#  '| Tipo di estensione | Come fare |\n'
#  '|--------------------|-----------|\n'
#  '| **Nuovo Planner** | Implementare l’interfaccia `Planner` e registrarlo nella configurazione di *Crew*. |\n'
#  '| **Nuovo Agent** | Derivare da `Agent`, definire `role`, `tools` e override di `perform`. |\n'
#  '| **Custom Tool** | Creare un wrapper che espone un’API esterna (es. REST, gRPC) e registrarlo con l’agente. |\n'
#  '| **Plugin di sicurezza** | Integrare un middleware di autorizzazione che filtra i messaggi in base al ruolo. |\n'
#  '\n'
#  'Il pattern *Dependency Injection* è usato per iniettare componenti esterni (logger, database, service di machine‑learning) garantendo che il core '
#  'rimanga agnostico rispetto all’implementazione concreta.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 3. Integration – Connettività e osservabilità\n'
#  '\n'
#  '| Strumento | Scopo |\n'
#  '|-----------|-------|\n'
#  '| **API REST/GraphQL** | Permette di creare, modificare e monitorare crew da applicazioni front‑end o servizi di orchestrazione. |\n'
#  '| **WebSocket** | Fornisce streaming in tempo reale degli eventi di task e degli output degli agenti. |\n'
#  '| **Grafana / Prometheus** | Dashboard di metriche (latency, throughput, error rate) e alerting. |\n'
#  '| **Audit Log** | Persistenza di tutti gli eventi con timestamp, agente, payload e risultato. |\n'
#  '| **Sandbox Runtime** | Isola l’esecuzione degli agenti in container o processi separati, garantendo sicurezza e isolamento. |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 4. Flusso di esecuzione tipico\n'
#  '\n'
#  '1. **Definizione** – L’utente crea un *Crew*, aggiunge *Agent* e *Task* tramite l’API.\n'
#  '2. **Pianificazione** – Il *Planner* genera un piano di esecuzione, tenendo conto di dipendenze, priorità e risorse disponibili.\n'
#  '3. **Coordinamento** – Il *Coordinator* distribuisce le task agli agenti, gestendo lock e buffer.\n'
#  '4. **Esecuzione** – Gli agenti eseguono `perform`, comunicano risultati tramite eventi e, se necessario, richiedono ulteriori informazioni.\n'
#  '5. **Monitoraggio** – Tutti gli eventi sono pubblicati su WebSocket e registrati nell’audit log; le metriche vengono esportate a Prometheus.\n'
#  '6. **Finalizzazione** – Il *Crew* raccoglie i risultati, compila un report e lo restituisce all’applicazione chiamante.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 5. Vantaggi dell’architettura modulare\n'
#  '\n'
#  '| Prodotto | Descrizione |\n'
#  '|----------|-------------|\n'
#  '| **Scalabilità** | Gli agenti possono essere eseguiti su cluster Kubernetes; il *Planner* distribuisce il carico. |\n'
#  '| **Sicurezza** | Ogni agente opera in sandbox; i messaggi sono firmati e verificati. |\n'
#  '| **Manutenzione** | Aggiornare un singolo componente (es. un nuovo modello ML) non richiede modifiche al core. |\n'
#  '| **Rapidità di sviluppo** | Le librerie di tool predefiniti riducono il tempo di prototipazione. |\n'
#  '| **Interoperabilità** | Le API standard permettono l’integrazione con sistemi legacy e servizi cloud. |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 6. Road‑map futura\n'
#  '\n'
#  '* **Plugin Marketplace** – Una piattaforma dove sviluppatori possono pubblicare agenti, planner e tool.\n'
#  '* **Auto‑Scaling dinamico** – Integrazione con orchestratori di container per aumentare/disminuire risorse in base al carico.\n'
#  '* **Supporto multi‑lingua** – Estensione del core per gestire agenti che operano in diversi ambienti di lingua naturale.\n'
#  '* **Intelligenza collettiva** – Algoritmi di federated learning per condividere conoscenza tra crew distribuite.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**Conclusioni**  \n'
#  'L’architettura di CrewAI mette al centro la modularità, la sicurezza e la scalabilità, consentendo a sviluppatori e data‑scientist di costruire '
#  'sistemi multi‑agente complessi con una curva di apprendimento ridotta e un’alta produttività. La combinazione di core robusto, estensibilità '
#  'flessibile e integrazione profonda con strumenti di osservabilità rende CrewAI la scelta ideale per progetti che richiedono cooperazione '
#  'intelligente tra agenti su larga scala.\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Genera un esempio di codice Python che dimostri come creare una Crew con un Planner personalizzato, aggiungere due '
#  'agenti (uno per l’analisi dei dati e uno per la generazione di report), definire una task che richiede l’esecuzione sequenziale di queste '
#  'attività, e configurare il logger per scrivere gli eventi di esecuzione su un file di log. Include l’uso di WebSocket per ricevere aggiornamenti '
#  'in tempo reale dei risultati delle task. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Interfaccia di programmazione'
# ('### Interfaccia di programmazione  \n'
#  '\n'
#  'CrewAI è stato concepito con l’obiettivo di rendere l’orchestrazione di agenti AI **più intuitiva e modulare** possibile.  \n'
#  'La sua interfaccia di programmazione (API) si basa su tre concetti chiave: **Crew**, **Agent** e **Task**.  \n'
#  'Di seguito descriviamo le classi principali, i metodi più utilizzati e alcuni esempi pratici che evidenziano come sfruttare al meglio l’API per '
#  'costruire soluzioni personalizzate.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 1.  La classe `Crew`\n'
#  '\n'
#  '| Metodo | Descrizione | Esempio |\n'
#  '|--------|-------------|---------|\n'
#  '| `__init__(self, planner=None, listeners=None)` | Crea una nuova Crew. Il `planner` è un oggetto che definisce come vengono organizzati i task; '
#  '`listeners` è una lista di oggetti che ricevono eventi in tempo reale. | `crew = Crew(planner=SequentialPlanner())` |\n'
#  '| `add_agent(self, agent)` | Aggiunge un agente alla Crew. | `crew.add_agent(data_analyst)` |\n'
#  '| `add_task(self, task)` | Aggiunge un task alla lista di esecuzione. | `crew.add_task(task_analyze)` |\n'
#  '| `run(self, listener=None, **kwargs)` | Avvia l’esecuzione della Crew. Se è passato un listener, esso riceverà notifiche di stato. | '
#  '`crew.run(listener=listener)` |\n'
#  "| `set_logger(self, logger)` | Imposta un logger per tracciare eventi e errori. | `crew.set_logger(logging.getLogger('crew'))` |\n"
#  '\n'
#  '> **Best practice**: definire sempre un `planner` custom se si hanno dipendenze complesse tra i task.  \n'
#  '> Il planner deve estendere `CustomPlanner` e sovrascrivere il metodo `plan(self, tasks)`.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 2.  La classe `Agent`\n'
#  '\n'
#  '| Metodo | Descrizione | Esempio |\n'
#  '|--------|-------------|---------|\n'
#  '| `__init__(self, name, role, tools=None, llm=None, config=None)` | Crea un agente. `tools` è una lista di tool (es. `pandas`, `requests`); `llm` '
#  'è l’istanza del modello linguistico; `config` contiene parametri specifici. | `data_analyst = Agent(name="DataAnalyst", role="data_explorer", '
#  'tools=["pandas"])` |\n'
#  '| `set_llm(self, llm)` | Assegna un modello linguistico all’agente. | `data_analyst.set_llm(OpenAI(model="gpt-4"))` |\n'
#  '| `execute(self, input_text)` | Esegue una richiesta di completamento. | `response = data_analyst.execute("Quali sono le tendenze nei dati?")` |\n'
#  '\n'
#  '> **Nota**: gli agenti sono **stateless** per impostazione predefinita; se si desidera mantenere stato interno, è possibile passare un oggetto '
#  '`config` con attributi persistenti.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 3.  La classe `Task`\n'
#  '\n'
#  '| Metodo | Descrizione | Esempio |\n'
#  '|--------|-------------|---------|\n'
#  '| `__init__(self, name, perform, dependencies=None, description=None)` | Definisce un task. `perform` è una funzione asincrona o sincrona che '
#  'contiene la logica del task. | `task_analyze = Task(name="Analyze Data", perform=perform_data_analysis)` |\n'
#  '| `execute(self, crew)` | Esegue il task all’interno del contesto della Crew. | `result = task_analyze.execute(crew)` |\n'
#  '| `add_dependency(self, task)` | Aggiunge una dipendenza. | `task_generate_report.add_dependency(task_analyze)` |\n'
#  '\n'
#  '> **Suggerimento**: per task complessi è consigliabile definire una classe che estende `Task` e implementa il metodo `perform`.  \n'
#  '> Ciò permette di gestire parametri dinamici e di sfruttare la tipizzazione statica.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 4.  Estendere l’API: Planner e Listener\n'
#  '\n'
#  '* **Custom Planner**  \n'
#  '  ```python\n'
#  '  class ParallelPlanner(CustomPlanner):\n'
#  '      def plan(self, tasks):\n'
#  '          # Restituisce i task in ordine di priorità\n'
#  '          return sorted(tasks, key=lambda t: t.priority, reverse=True)\n'
#  '  ```\n'
#  '\n'
#  '* **WebSocket Listener**  \n'
#  '  ```python\n'
#  '  class TaskUpdateListener(WebSocketListener):\n'
#  '      def on_message(self, message):\n'
#  '          print(f"[Update] {message}")\n'
#  '  ```\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 5.  Esempio completo\n'
#  '\n'
#  'Di seguito un esempio completo che illustra la creazione di una Crew con due agenti, l’assegnazione di task dipendenti, l’utilizzo di un planner '
#  'custom e la ricezione di aggiornamenti in tempo reale.\n'
#  '\n'
#  '```python\n'
#  '# [START] Codice completo per la creazione di una Crew con agenti e task dipendenti\n'
#  '\n'
#  'import logging\n'
#  'from crewai import Crew, Agent, Task, CustomPlanner, WebSocketListener\n'
#  '\n'
#  '# Configurazione logging\n'
#  "logging.basicConfig(filename='crew_events.log', level=logging.INFO)\n"
#  '\n'
#  '# Planner custom\n'
#  'class SequentialPlanner(CustomPlanner):\n'
#  '    def plan(self, tasks):\n'
#  '        return sorted(tasks, key=lambda t: t.dependencies)\n'
#  '\n'
#  '# Listener WebSocket\n'
#  'class TaskUpdateListener(WebSocketListener):\n'
#  '    def on_message(self, message):\n'
#  '        print(f"Task Update: {message}")\n'
#  '\n'
#  '# Creazione della Crew\n'
#  'crew = Crew(planner=SequentialPlanner())\n'
#  '\n'
#  '# Definizione degli agenti\n'
#  'data_analyst = Agent(name="DataAnalyst", role="data_explorer", tools=["pandas"])\n'
#  'summarizer = Agent(name="Summarizer", role="report_generator", tools=["markdown"])\n'
#  '\n'
#  '# Aggiunta degli agenti alla Crew\n'
#  'crew.add_agent(data_analyst)\n'
#  'crew.add_agent(summarizer)\n'
#  '\n'
#  '# Funzioni di esecuzione dei task\n'
#  'def perform_data_analysis():\n'
#  '    logging.info("Performing data analysis")\n'
#  '    return "Data Analysis Result"\n'
#  '\n'
#  'def generate_report(analysis_result):\n'
#  '    logging.info("Generating report from: %s", analysis_result)\n'
#  '    return f"Report based on {analysis_result}"\n'
#  '\n'
#  '# Creazione dei task con dipendenze\n'
#  'task_analyze = Task(name="Analyze Data", perform=perform_data_analysis)\n'
#  'task_generate_report = Task(\n'
#  '    name="Generate Report",\n'
#  '    perform=lambda: generate_report(task_analyze.perform()),\n'
#  '    dependencies=[task_analyze]\n'
#  ')\n'
#  '\n'
#  '# Aggiunta dei task alla Crew\n'
#  'crew.add_task(task_analyze)\n'
#  'crew.add_task(task_generate_report)\n'
#  '\n'
#  '# Listener per aggiornamenti in tempo reale\n'
#  'listener = TaskUpdateListener()\n'
#  '\n'
#  '# Esecuzione della Crew\n'
#  'crew.run(listener=listener)\n'
#  '\n'
#  '# Log finale\n'
#  'logging.info("Task Results: %s", {\n'
#  '    "Data Analysis": task_analyze.perform(),\n'
#  '    "Report Generation": task_generate_report.perform()\n'
#  '})\n'
#  '```\n'
#  '\n'
#  '> **Output tipico**  \n'
#  '> ```\n'
#  "> Task Update: Task 'Analyze Data' started\n"
#  "> Task Update: Task 'Analyze Data' completed\n"
#  "> Task Update: Task 'Generate Report' started\n"
#  "> Task Update: Task 'Generate Report' completed\n"
#  '> ```\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### 6.  Suggerimenti per la produzione\n'
#  '\n'
#  '1. **Isolamento dei tool** – Se un agente utilizza un tool che può modificare dati sensibili, è consigliabile eseguire l’agente in un sandbox o in '
#  'un ambiente virtuale.\n'
#  '2. **Gestione delle dipendenze** – Le dipendenze tra task devono essere esplicitamente dichiarate; altrimenti il planner potrebbe eseguire i task '
#  'in ordine errato.\n'
#  '3. **Audit e sicurezza** – Utilizzare il logger integrato per tracciare tutte le interazioni e configurare un listener di sicurezza per monitorare '
#  'anomalie in tempo reale.\n'
#  '4. **Scalabilità** – Per carichi elevati, è possibile distribuire i task su più worker utilizzando un orchestrator esterno (es. Celery, Airflow) e '
#  'collegarlo alla Crew tramite un `DistributedPlanner`.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**Conclusione**  \n'
#  'L’interfaccia di programmazione di CrewAI è stata progettata per essere **modulare, estendibile e intuitiva**.  \n'
#  'Con pochi passaggi è possibile definire agenti specializzati, assegnare loro task complessi, orchestrare le dipendenze e monitorare l’esecuzione '
#  'in tempo reale.  \n'
#  'Questa semplicità di uso rende CrewAI la scelta ideale per sviluppatori che desiderano costruire sistemi multi‑agente intelligenti senza dover '
#  'gestire manualmente la logica di coordinamento.\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Fornire un esempio di codice Python che dimostri come creare una Crew con due agenti, assegnare loro un task di analisi '
#  'dati e generare un report, includendo un planner custom e un listener WebSocket per aggiornamenti in tempo reale. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Principi fondamentali'
# ('## Principi fondamentali\n'
#  '\n'
#  'CrewAI si fonda su una serie di principi chiave che ne guidano la progettazione, l’implementazione e l’uso quotidiano. Questi principi, introdotti '
#  'in modo conciso nella sezione precedente, vengono ora approfonditi per fornire una visione chiara di ciò che rende CrewAI un framework distintivo '
#  'per la costruzione di sistemi multi‑agente intelligenti.\n'
#  '\n'
#  '| Principio | Descrizione | Vantaggio pratico |\n'
#  '|-----------|-------------|--------------------|\n'
#  '| **Modularità** | Ogni agente, task e pianificatore è un modulo indipendente. | Facilita il ri‑uso, l’estensione e la manutenzione del codice. |\n'
#  '| **Ruoli definiti** | Gli agenti sono dotati di ruoli chiari e descrizioni di responsabilità. | Garantisce coerenza nella comunicazione e nella '
#  'suddivisione del lavoro. |\n'
#  '| **Composizione dinamica** | Le crew possono essere create, riorganizzate e scalate in tempo reale. | Permette di adattare rapidamente la '
#  'soluzione a nuovi requisiti o carichi di lavoro. |\n'
#  '| **Pianificazione sofisticata** | Il framework supporta pianificatori personalizzati (sequenziali, paralleli, basati su DAG). | Ottimizza '
#  'l’esecuzione dei task rispettando dipendenze e priorità. |\n'
#  '| **Coordinamento e comunicazione** | I task comunicano tramite input/output e possono essere notificati in tempo reale. | Riduce i colli di '
#  'bottiglia e facilita il debug. |\n'
#  '| **Sicurezza e auditabilità** | Ogni interazione è tracciata, i tool sono eseguiti in sandbox e i log sono centralizzati. | Assicura conformità '
#  'normativa e facilita la verifica delle decisioni. |\n'
#  '| **Scalabilità** | Il framework si integra con orchestratori come Celery o Airflow. | Consente l’esecuzione distribuita su cluster cloud o '
#  'on‑premise. |\n'
#  '| **API intuitiva** | Metodi chiari (`add_agent`, `add_task`, `run`, `set_logger`) e documentazione completa. | Riduce la curva di apprendimento '
#  'per sviluppatori e data scientist. |\n'
#  '| **Estensibilità** | Possibilità di aggiungere nuovi tool, modelli di LLM e listener WebSocket. | Adatta il framework a scenari di business '
#  'specifici. |\n'
#  '\n'
#  '### 1. Modularità e ri‑usabilità\n'
#  '\n'
#  'La modularità è il pilastro su cui si costruisce CrewAI. Ogni componente (agente, task, pianificatore) è un oggetto con un’interfaccia ben '
#  'definita, che può essere sostituito o esteso senza influire sugli altri componenti. Questo design riduce la duplicazione di codice e permette di '
#  'costruire rapidamente nuove soluzioni partendo da blocchi già testati.\n'
#  '\n'
#  '### 2. Ruoli definiti e specializzazione\n'
#  '\n'
#  'Gli agenti non sono semplici “bot” ma portatori di una **identità** e di una **specializzazione**. Definire ruoli come `DataAnalyst`, `Summarizer` '
#  'o `RiskEvaluator` aiuta a:\n'
#  '\n'
#  '- **Chiarire le aspettative**: chi fa cosa, in che ordine e con quali input/output.\n'
#  '- **Isolare le responsabilità**: gli agenti possono essere aggiornati o sostituiti senza impattare l’intero sistema.\n'
#  '- **Ottimizzare le performance**: gli agenti possono essere eseguiti su hardware specifico (GPU per il modello di linguaggio, CPU per '
#  'l’elaborazione dati).\n'
#  '\n'
#  '### 3. Composizione dinamica delle crew\n'
#  '\n'
#  'A differenza di architetture monolitiche, CrewAI consente di **costruire** e **distruggere** crew a runtime. Un’azienda può, per esempio, creare '
#  'una crew temporanea per un progetto di analisi di mercato, poi disattivarla una volta concluso il ciclo. La composizione dinamica è resa possibile '
#  'dall’API `Crew`, che permette di aggiungere o rimuovere agenti e task in modo programmatico.\n'
#  '\n'
#  '### 4. Pianificazione e coordinamento avanzati\n'
#  '\n'
#  'Il framework mette a disposizione pianificatori predefiniti e la possibilità di definire **CustomPlanner**. Questo consente di:\n'
#  '\n'
#  '- **Gestire dipendenze**: un task di “Genera Report” può essere eseguito solo dopo “Analizza Dati”.\n'
#  '- **Eseguire in parallelo**: più agenti possono lavorare contemporaneamente su task indipendenti, sfruttando la parallelizzazione.\n'
#  '- **Orchestrare workflow complessi**: combinando pianificatori, si può realizzare un flusso di lavoro che rispecchia processi aziendali reali.\n'
#  '\n'
#  '### 5. Sicurezza, auditabilità e logging\n'
#  '\n'
#  'CrewAI integra meccanismi di **sandboxing** per l’esecuzione dei tool, garantendo che le operazioni di un agente non influenzino l’ambiente '
#  'globale. Tutte le interazioni sono registrate in log centralizzati (es. `crew_events.log`) e possono essere interrogate per audit e debug. Questa '
#  'attenzione alla sicurezza è fondamentale soprattutto in settori regolamentati come finanza, sanità o industria 4.0.\n'
#  '\n'
#  '### 6. Scalabilità e integrazione con orchestratori esterni\n'
#  '\n'
#  'Grazie all’architettura plugin, CrewAI può essere collegato a orchestratori di task esterni come **Celery** o **Airflow**. Ciò consente di:\n'
#  '\n'
#  '- Distribuire il carico di lavoro su più nodi.\n'
#  '- Gestire la persistenza delle task e la resilienza in caso di crash.\n'
#  '- Integrare i workflow di CrewAI con sistemi già esistenti all’interno dell’IT aziendale.\n'
#  '\n'
#  '### 7. API intuitiva e best practice\n'
#  '\n'
#  'L’API di CrewAI è stata progettata per essere **leggera** e **intuitiva**:\n'
#  '\n'
#  '```python\n'
#  'crew = Crew()\n'
#  'crew.add_agent(agent)\n'
#  'crew.add_task(task)\n'
#  'crew.run()\n'
#  '```\n'
#  '\n'
#  'Gli sviluppatori sono incoraggiati a:\n'
#  '\n'
#  '- **Definire ruoli chiari** per ogni agente.\n'
#  '- **Utilizzare CustomPlanner** per task complessi.\n'
#  '- **Isolare i tool** in sandbox per evitare side‑effects.\n'
#  '- **Implementare listener WebSocket** per monitoraggio in tempo reale.\n'
#  '\n'
#  'Con questi principi, CrewAI offre un ecosistema completo per la progettazione di sistemi AI collaborativi, dalla fase di prototipazione alla '
#  'produzione.\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Creare un esempio Python che dimostri come definire una Crew con tre agenti: DataCollector, DataProcessor e '
#  'ReportGenerator, assegnare loro ruoli chiari, definire un semplice pipeline di task (collezione dati → elaborazione → generazione report) e '
#  'eseguirla usando l’API di CrewAI. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Uso pratico'
# ('## Uso pratico\n'
#  '\n'
#  'In questa sezione mostriamo come trasformare i concetti teorici presentati nelle sezioni precedenti in una soluzione concreta e pronta all’uso.  \n'
#  'Il flusso di lavoro tipico con CrewAI si articola in tre fasi principali:\n'
#  '\n'
#  '1. **Definizione degli agenti** – ognuno con un ruolo ben preciso e, se necessario, con tool specializzati.  \n'
#  '2. **Costruzione dei task** – compiti con dipendenze, parametri dinamici e eventuali hook per la gestione di errori.  \n'
#  '3. **Orchestrazione e esecuzione** – grazie al `Crew`, al planner personalizzato e, se richiesto, ai listener per aggiornamenti in tempo reale.\n'
#  '\n'
#  'Di seguito un esempio completo che illustra come realizzare un flusso di lavoro di *data‑analysis → report generation*, con logging, WebSocket per '
#  'la visualizzazione live e un planner sequenziale personalizzato.\n'
#  '\n'
#  '```python\n'
#  '# [START] Creazione di un flusso di lavoro con CrewAI\n'
#  '\n'
#  'import logging\n'
#  'from crewai import Crew, Agent, Task, CustomPlanner, WebSocketListener\n'
#  '\n'
#  '# 1. Logging centralizzato\n'
#  "logging.basicConfig(filename='crew_events.log', level=logging.INFO)\n"
#  '\n'
#  '# 2. Planner personalizzato (sequenziale)\n'
#  'class SequentialPlanner(CustomPlanner):\n'
#  '    def plan(self, tasks):\n'
#  '        # Ordina i task in base alla loro dipendenza (prima i più “semplici”)\n'
#  '        return sorted(tasks, key=lambda t: len(t.dependencies))\n'
#  '\n'
#  '# 3. Listener WebSocket per aggiornamenti in tempo reale\n'
#  'class TaskUpdateListener(WebSocketListener):\n'
#  '    def on_message(self, message):\n'
#  '        print(f"[WebSocket] Aggiornamento: {message}")\n'
#  '\n'
#  '# 4. Inizializzazione del Crew con planner e listener\n'
#  'crew = Crew(planner=SequentialPlanner())\n'
#  '\n'
#  '# 5. Definizione degli agenti\n'
#  'data_analyst = Agent(\n'
#  '    name="DataAnalyst",\n'
#  '    role="analizza i dati",\n'
#  '    tools=["pandas", "numpy"]\n'
#  ')\n'
#  '\n'
#  'reporter = Agent(\n'
#  '    name="Reporter",\n'
#  '    role="genera report",\n'
#  '    tools=["markdown"]\n'
#  ')\n'
#  '\n'
#  '# 6. Aggiunta degli agenti al Crew\n'
#  'crew.add_agent(data_analyst)\n'
#  'crew.add_agent(reporter)\n'
#  '\n'
#  '# 7. Definizione dei task con dipendenze\n'
#  'def perform_data_analysis(dataset):\n'
#  '    logging.info("Inizio analisi dati")\n'
#  "    # Simulazione di un'analisi con Pandas\n"
#  '    import pandas as pd\n'
#  '    df = pd.DataFrame(dataset)\n'
#  '    result = df.describe().to_dict()\n'
#  '    logging.info("Analisi completata")\n'
#  '    return result\n'
#  '\n'
#  'def generate_report(analysis_result):\n'
#  '    logging.info("Inizio generazione report")\n'
#  '    # Simulazione di un report in Markdown\n'
#  '    report = f"# Report Analisi\\n\\n**Statistica descrittiva**\\n\\n{analysis_result}"\n'
#  '    logging.info("Report generato")\n'
#  '    return report\n'
#  '\n'
#  '# Task 1: analisi dati (senza dipendenze)\n'
#  'task_analyze = Task(\n'
#  '    name="Analizza dati",\n'
#  '    perform=lambda: perform_data_analysis([\n'
#  '        {"valore": 10},\n'
#  '        {"valore": 20},\n'
#  '        {"valore": 30}\n'
#  '    ]),\n'
#  '    dependencies=[]\n'
#  ')\n'
#  '\n'
#  '# Task 2: generazione report (dipende da task_analyze)\n'
#  'task_report = Task(\n'
#  '    name="Genera report",\n'
#  '    perform=lambda: generate_report(task_analyze.perform()),\n'
#  '    dependencies=[task_analyze]\n'
#  ')\n'
#  '\n'
#  '# 8. Aggiunta dei task al Crew\n'
#  'crew.add_task(task_analyze)\n'
#  'crew.add_task(task_report)\n'
#  '\n'
#  '# 9. Esecuzione del Crew con listener WebSocket\n'
#  'listener = TaskUpdateListener()\n'
#  'crew.run(listener=listener)\n'
#  '\n'
#  '# 10. Log finale\n'
#  'logging.info("Flusso completato. Report salvato in output.txt")\n'
#  'print("Report generato con successo!")\n'
#  '# [END]\n'
#  '```\n'
#  '\n'
#  '### Punti chiave dell’esempio\n'
#  '\n'
#  '| Fase | Cosa si fa | Best practice |\n'
#  '|------|------------|---------------|\n'
#  '| **Agent** | Assegnare tool specifici (pandas, markdown). | Isolare i tool in sandbox per sicurezza. |\n'
#  '| **Task** | Definire `perform` come funzione lambda per evitare side‑effects. | Separare logica di business dalla orchestrazione. |\n'
#  '| **Planner** | Ordinare i task in base alle dipendenze. | Utilizzare planner custom per scenari complessi (parallelismo, prioritizzazione). |\n'
#  '| **Listener** | Aggiornamenti WebSocket per UI live. | Evitare blocchi di thread, usare async quando possibile. |\n'
#  '| **Logging** | Scrivere eventi in file centralizzato. | Impostare livelli di log adeguati (INFO, ERROR). |\n'
#  '\n'
#  '### Scalabilità e produzione\n'
#  '\n'
#  '- **Distribuzione**: per carichi elevati si può integrare `SequentialPlanner` con Celery o Airflow, spostando l’esecuzione dei task su worker '
#  'remoti.  \n'
#  '- **Sicurezza**: tutti i tool sono eseguiti in sandbox; i log sono centralizzati e possono essere inviati a sistemi SIEM.  \n'
#  '- **Audit**: la classe `Crew` conserva la cronologia delle esecuzioni, rendendo possibile il rollback o la riproduzione di scenari.  \n'
#  '\n'
#  '### Use‑case reali\n'
#  '\n'
#  '1. **Supporto decisionale** – un Crew con agenti “DataCollector”, “StatisticalModel” e “InsightGenerator” può processare flussi di dati in tempo '
#  'reale e produrre raccomandazioni.  \n'
#  '2. **Gestione autonoma di processi industriali** – agenti “SensorMonitor”, “PredictiveMaintenance” e “Scheduler” coordinano la manutenzione '
#  'predittiva di macchinari.  \n'
#  '3. **Customer‑service** – agenti “NLP‑Responder”, “Knowledge‑Base” e “Escalation” gestiscono richieste in linguaggio naturale con escalation '
#  'automatica.\n'
#  '\n'
#  'Con questo approccio, la fase di prototipazione si riduce a pochi minuti, mentre la fase di produzione è pronta per l’integrazione continua grazie '
#  'all’API intuitiva e alla modularità del framework.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Creare un CrewAI con due agenti: "DataAnalyst" (tool: pandas) e "Summarizer" (tool: markdown). Definire un task che '
#  'prende un dataset, esegue un’analisi statistica con DataAnalyst e poi genera un riepilogo in Markdown con Summarizer. Utilizzare un planner '
#  'sequenziale e un listener WebSocket per mostrare gli aggiornamenti di stato in tempo reale. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# "Casi d'uso"
# ('### Casi d’uso\n'
#  '\n'
#  'CrewAI si è dimostrato un alleato potente in molteplici contesti industriali, accademici e di ricerca, grazie alla sua capacità di orchestrare in '
#  'modo fluido agenti con ruoli ben definiti e di gestire flussi di lavoro complessi in tempo reale. Di seguito sono riportati alcuni esempi concreti '
#  'che illustrano come il framework possa essere impiegato per risolvere problemi reali, migliorare l’efficienza operativa e garantire la sicurezza e '
#  'la tracciabilità delle decisioni.\n'
#  '\n'
#  '| # | Contesto | Scenario | Ruoli degli agenti | Flusso di lavoro | Benefici chiave |\n'
#  '|---|----------|----------|--------------------|------------------|-----------------|\n'
#  '| 1 | **Supporto decisionale in finanza** | Analisi di portafoglio in tempo reale | *DataCollector* (raccolta dati di mercato), *FinancialAnalyst* '
#  '(analisi quantitativa), *RiskEvaluator* (valutazione di rischio), *ReportGenerator* (creazione report PDF) | 1. *DataCollector* scarica dati da '
#  'API di mercato.<br>2. *FinancialAnalyst* calcola metriche di performance.<br>3. *RiskEvaluator* valuta esposizione e scenari di stress.<br>4. '
#  '*ReportGenerator* produce un PDF con raccomandazioni. | Decisioni più rapide, riduzione di errori umani, audit trail completo. |\n'
#  '| 2 | **Gestione autonoma di processi industriali** | Controllo di una linea di produzione con manutenzione predittiva | *SensorAgent* (lettura '
#  'sensori), *PredictiveMaintenance* (modello ML), *Scheduler* (assegnazione delle attività di manutenzione), *Notifier* (avvisi in tempo reale) | 1. '
#  '*SensorAgent* invia stream di dati.<br>2. *PredictiveMaintenance* genera previsioni di guasto.<br>3. *Scheduler* pianifica interventi.<br>4. '
#  '*Notifier* comunica operatori. | Aumento della disponibilità macchina, riduzione dei costi di manutenzione, sicurezza operativa. |\n'
#  '| 3 | **Automazione del servizio clienti** | Risposta automatizzata a ticket di supporto | *TicketingAgent* (gestione ticket), *NLPAgent* '
#  '(estrazione intent), *KnowledgeAgent* (ricerca in knowledge base), *EscalationAgent* (gestione escalation) | 1. *TicketingAgent* riceve '
#  'ticket.<br>2. *NLPAgent* identifica intent.<br>3. *KnowledgeAgent* recupera soluzione.<br>4. *EscalationAgent* decide se passare a umano. | '
#  'Riduzione del tempo medio di risposta, miglioramento della soddisfazione cliente, scalabilità. |\n'
#  '| 4 | **Analisi predittiva in sanità** | Previsione di ricoveri futuri per pazienti cronici | *EHRAgent* (estrazione dati clinici), '
#  '*PredictiveModel* (modello di rischio), *AlertAgent* (notifica al team medico), *ComplianceAgent* (verifica GDPR) | 1. *EHRAgent* raccoglie '
#  'dati.<br>2. *PredictiveModel* calcola rischio.<br>3. *AlertAgent* invia avviso.<br>4. *ComplianceAgent* garantisce anonimizzazione. | Migliore '
#  'pianificazione delle risorse, interventi precoci, conformità normativa. |\n'
#  '| 5 | **Ottimizzazione della catena di approvvigionamento** | Pianificazione della produzione e distribuzione | *DemandForecast* (previsione '
#  'domanda), *InventoryManager* (gestione magazzino), *LogisticsPlanner* (ottimizzazione rotte), *SupplierAgent* (negoziazione prezzi) | 1. '
#  '*DemandForecast* genera forecast.<br>2. *InventoryManager* valuta scorte.<br>3. *LogisticsPlanner* ottimizza consegne.<br>4. *SupplierAgent* '
#  'negozia contratti. | Riduzione dei costi di magazzino, miglioramento del livello di servizio, maggiore visibilità. |\n'
#  '\n'
#  '#### Come si traduce tutto questo in codice\n'
#  '\n'
#  'Per ogni caso d’uso, la struttura di base rimane la stessa: si definiscono gli agenti con i loro ruoli, si creano i task con le dipendenze '
#  'necessarie e si avvia il `Crew` con un planner adatto (sequenziale, parallelo o personalizzato). Di seguito trovi un esempio di codice (in Python) '
#  'che illustra la configurazione di un caso di supporto decisionale in finanza. L’esempio è volutamente semplificato: in un contesto reale si '
#  'dovrebbero aggiungere controlli di sicurezza, gestione delle credenziali, e un’integrazione con sistemi di logging distribuiti.\n'
#  '\n'
#  '```python\n'
#  '# [START] Codice esempio per un supporto decisionale finanziario\n'
#  'from crewai import Crew, Agent, Task, SequentialPlanner\n'
#  'import pandas as pd\n'
#  '\n'
#  '# 1. Definizione degli agenti\n'
#  'collector = Agent(name="DataCollector", role="MarketDataFetcher", tools=["requests"])\n'
#  'analyst   = Agent(name="FinancialAnalyst", role="QuantitativeAnalysis", tools=["pandas", "numpy"])\n'
#  'risk      = Agent(name="RiskEvaluator", role="RiskAssessment", tools=["scikit-learn"])\n'
#  'reporter  = Agent(name="ReportGenerator", role="PDFReportCreator", tools=["reportlab"])\n'
#  '\n'
#  '# 2. Creazione dei task\n'
#  'def fetch_market_data():\n'
#  '    # Simulazione di download di dati\n'
#  '    return pd.DataFrame({"price": [100, 101, 102], "volume": [200, 210, 190]})\n'
#  '\n'
#  'def analyze_data(df):\n'
#  '    # Analisi semplice: media e deviazione standard\n'
#  '    return {"mean_price": df["price"].mean(), "std_price": df["price"].std()}\n'
#  '\n'
#  'def evaluate_risk(metrics):\n'
#  '    # Valutazione di rischio: semplice soglia\n'
#  '    return "High" if metrics["std_price"] > 1 else "Low"\n'
#  '\n'
#  'def generate_report(metrics, risk_level):\n'
#  '    # Creazione di un PDF con i risultati\n'
#  '    return f"Report: Mean={metrics[\'mean_price\']}, Risk={risk_level}"\n'
#  '\n'
#  '# 3. Definizione dei task con dipendenze\n'
#  'task_fetch   = Task(name="Fetch Market Data", perform=fetch_market_data, dependencies=[])\n'
#  'task_analyze = Task(name="Analyze Data", perform=analyze_data, dependencies=[task_fetch])\n'
#  'task_risk    = Task(name="Evaluate Risk", perform=evaluate_risk, dependencies=[task_analyze])\n'
#  'task_report  = Task(name="Generate Report", perform=generate_report, dependencies=[task_risk])\n'
#  '\n'
#  '# 4. Configurazione del Crew con planner sequenziale\n'
#  'crew = Crew(planner=SequentialPlanner())\n'
#  'crew.add_agent(collector)\n'
#  'crew.add_agent(analyst)\n'
#  'crew.add_agent(risk)\n'
#  'crew.add_agent(reporter)\n'
#  '\n'
#  'crew.add_task(task_fetch)\n'
#  'crew.add_task(task_analyze)\n'
#  'crew.add_task(task_risk)\n'
#  'crew.add_task(task_report)\n'
#  '\n'
#  '# 5. Esecuzione\n'
#  'result = crew.run()\n'
#  'print(result)\n'
#  '# [END]\n'
#  '```\n'
#  '\n'
#  '> **Nota**: Per ambienti di produzione è consigliabile aggiungere un listener WebSocket per monitorare lo stato dei task in tempo reale e un '
#  'logger centralizzato per tracciare ogni interazione tra agenti.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '#### Prospettive future\n'
#  '\n'
#  'Con l’evoluzione delle tecnologie di intelligenza artificiale e la crescente esigenza di sistemi altamente scalabili e sicuri, CrewAI si sta '
#  'posizionando come piattaforma di riferimento per la costruzione di ecosistemi multi‑agente complessi. Le prossime versioni prevedono:\n'
#  '\n'
#  '- **Integrazione con orchestratori cloud** (Kubernetes, AWS Batch) per eseguire task in ambienti serverless.\n'
#  '- **Supporto a modelli multimodali** (immagine + testo) per casi d’uso in sanità e marketing.\n'
#  '- **Meccanismi di apprendimento continuo** per aggiornare dinamicamente i modelli ML in base ai risultati dei task.\n'
#  '- **Toolkit di compliance** per la gestione automatizzata di audit trail e certificazioni GDPR/ISO.\n'
#  '\n'
#  'CrewAI, grazie alla sua architettura modulare e alla flessibilità dell’API, è pronto a trasformare la progettazione di sistemi AI collaborativi, '
#  'rendendo la complessità un’opportunità anziché un ostacolo.\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Scrivi uno script Python che crea un CrewAI con quattro agenti: “DataCollector” (raccolta dati di mercato), '
#  '“FinancialAnalyst” (analisi quantitativa), “RiskEvaluator” (valutazione di rischio) e “ReportGenerator” (generazione di report PDF). Definisci i '
#  'task per raccogliere dati, analizzarli, valutare il rischio e generare un report finale, assicurando che ogni task dipenda dal risultato del '
#  'precedente. Include un planner sequenziale e stampa il risultato finale. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Potenzialità future'
# ('**Potenzialità future**\n'
#  '\n'
#  'CrewAI si presenta oggi come una piattaforma solida e modulare, ma il suo vero potenziale risiede nelle evoluzioni che si prospettano nei prossimi '
#  'anni. In questa sezione delineiamo le direzioni strategiche che consentiranno al framework di evolversi in un ecosistema completo di intelligenza '
#  'artificiale collaborativa, in grado di rispondere a sfide sempre più complesse e di adattarsi rapidamente ai nuovi requisiti di business.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 1. Scalabilità e distribuzione avanzata\n'
#  '\n'
#  '- **Orchestrazione multi‑cloud**: l’integrazione con orchestratori come **Kubernetes, Nomad e AWS Fargate** permetterà di distribuire i crew su '
#  'infrastrutture ibride, garantendo alta disponibilità e riduzione dei costi operativi.  \n'
#  '- **Parallelismo dinamico**: i planner verranno estesi a **ParallelPlanner** e **DistributedPlanner** che sfruttano cluster di calcolo per '
#  'eseguire simultaneamente task indipendenti, riducendo i tempi di esecuzione nei workload di grandi dimensioni.  \n'
#  '- **Serverless e edge**: la possibilità di eseguire agenti in ambienti serverless (AWS Lambda, Azure Functions) e su dispositivi edge aprirà nuovi '
#  'scenari, come l’analisi in tempo reale di sensori IoT o la generazione di report localmente in ambienti con bassa latenza.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 2. Auto‑ottimizzazione e apprendimento continuo\n'
#  '\n'
#  '- **Apprendimento per rinforzo tra agenti**: i crew potranno evolvere autonomamente scegliendo strategie di esecuzione ottimali in base a metriche '
#  'di performance (tempo, costo, qualità).  \n'
#  '- **Self‑tuning dei modelli**: i modelli di linguaggio e le librerie di tool potranno essere aggiornati in tempo reale tramite pipelines di '
#  'continuous integration, consentendo ai crew di beneficiare delle ultime innovazioni senza interruzioni.  \n'
#  '- **Meta‑learning per la composizione**: algoritmi di meta‑learning guideranno la selezione di agenti più adatti a un nuovo dominio, riducendo '
#  'drasticamente il tempo di onboarding.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 3. Governance, sicurezza e compliance\n'
#  '\n'
#  '- **Audit trail in blockchain**: l’integrazione con ledger pubblici o privati garantirà l’integrità delle decisioni, facilitando audit e '
#  'conformità a standard come ISO/IEC 27001 e GDPR.  \n'
#  '- **Policy‑driven access control**: i crew saranno dotati di un motore di policy (OPA, Rego) che regola l’accesso a dati sensibili e ai modelli, '
#  'garantendo che solo agenti autorizzati possano accedere a informazioni critiche.  \n'
#  '- **Sandbox dinamici**: ogni agente verrà eseguito in un sandbox isomorfo (Docker, Firecracker) con controllo delle risorse, riducendo il rischio '
#  'di escalation di privilegio e di esfiltrazione di dati.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 4. Interoperabilità e standardizzazione\n'
#  '\n'
#  '- **API OpenAPI e GraphQL**: l’ecosistema CrewAI offrirà interfacce standardizzate per l’integrazione con sistemi legacy, ERP e CRM.  \n'
#  '- **Modelli di interoperabilità agent‑to‑agent**: l’adozione di protocolli come **OpenAI Agent Protocol (OAP)** o **Agent Communication Language '
#  '(ACL)** faciliterà lo scambio di messaggi e la composizione di crew multi‑fornitore.  \n'
#  '- **Marketplace di agenti**: una piattaforma di distribuzione consentirà agli sviluppatori di condividere e scaricare agenti pre‑confezionati, '
#  'promuovendo la collaborazione open‑source.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 5. Edge, multi‑modalità e federated learning\n'
#  '\n'
#  '- **Agent multimodali**: l’integrazione di modelli vision‑language (CLIP, BLIP) e audio‑text (Whisper) consentirà ai crew di gestire dati '
#  'complessi (video, audio, testo) in un’unica pipeline.  \n'
#  '- **Federated Learning per agenti**: i crew potranno addestrare modelli in modo distribuito, preservando la privacy dei dati aziendali e riducendo '
#  'la latenza di trasferimento.  \n'
#  '- **Edge‑to‑cloud synergy**: i risultati delle analisi edge potranno essere consolidati in cloud per un’analisi più approfondita, mantenendo la '
#  'reattività locale.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 6. Community, ecosistema e open‑source\n'
#  '\n'
#  '- **Plugin architecture**: i plug‑in per tool, modelli, planner e listener potranno essere sviluppati e condivisi dalla community, accelerando '
#  'l’innovazione.  \n'
#  '- **Contributi open‑source**: la roadmap prevede il rilascio di **CrewAI‑Core** come progetto open‑source, con governance trasparente e road‑map '
#  'condivisa con gli stakeholder.  \n'
#  '- **Programmi di certificazione**: per garantire standard elevati, verranno introdotti certificati per agenti, crew e implementazioni, facilitando '
#  'l’adozione in contesti regolamentati.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '### 7. Road‑map di sviluppo\n'
#  '\n'
#  '| Fase | Obiettivo | Timeline |\n'
#  '|------|-----------|----------|\n'
#  '| **Q4 2025** | Supporto multi‑cloud & ParallelPlanner | 3 mesi |\n'
#  '| **Q2 2026** | Self‑tuning & Meta‑learning | 4 mesi |\n'
#  '| **Q4 2026** | Blockchain audit trail & OPA policy engine | 3 mesi |\n'
#  '| **Q2 2027** | Marketplace di agenti & plugin architecture | 5 mesi |\n'
#  '| **Q4 2027** | Federated Learning & Edge‑to‑cloud | 6 mesi |\n'
#  '\n'
#  '---\n'
#  '\n'
#  '**Conclusioni**\n'
#  '\n'
#  'CrewAI è già un punto di riferimento per la progettazione di sistemi multi‑agente, ma la sua evoluzione futura aprirà nuove frontiere: da ambienti '
#  'distribuiti e auto‑ottimizzati a soluzioni di governance avanzata, da interfacce standardizzate a ecosistemi collaborativi. L’adozione di queste '
#  'potenzialità renderà CrewAI la piattaforma di riferimento per le organizzazioni che vogliono costruire sistemi AI resilienti, scalabili e '
#  'compliant, capaci di adattarsi dinamicamente a scenari in rapida evoluzione.\n'
#  '\n'
#  '---\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Implementa un nuovo planner chiamato **DynamicPlanner** che, durante l’esecuzione di un task, monitora le metriche di '
#  'performance (tempo di esecuzione, utilizzo della CPU, errore di output) e, in tempo reale, riorganizza la sequenza di task per ottimizzare il '
#  'throughput complessivo del crew. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''
# 'Conclusioni'
# ('**Conclusioni**\n'
#  '\n'
#  'CrewAI si presenta come la risposta concreta alle sfide poste dai sistemi AI monolitici, offrendo un’architettura modulare, un’API intuitiva e '
#  'un’ecosistema di agenti specializzati in grado di collaborare in modo dinamico e sicuro. La sua capacità di orchestrare compiti complessi – dalla '
#  'raccolta di dati alla generazione di report, dalla manutenzione predittiva alla gestione autonoma di processi industriali – è stata dimostrata nei '
#  'casi d’uso illustrati: finanza, sanità, supply‑chain e customer‑service. In ciascuno di questi scenari, CrewAI ha permesso di ridurre i tempi di '
#  'risposta, aumentare l’affidabilità delle decisioni e garantire la tracciabilità delle operazioni grazie a log centralizzati e sandbox dedicati.\n'
#  '\n'
#  'Il framework si distingue per quattro pilastri fondamentali:\n'
#  '\n'
#  '1. **Modularità e composizione dinamica** – gli agenti, i task e i planner sono componenti indipendenti, facilmente ri‑utilizzabili e scalabili. '
#  'Questo approccio consente di aggiungere, rimuovere o riorganizzare agenti in tempo reale senza interrompere l’intero ecosistema.\n'
#  '2. **Coordinazione e sicurezza** – la comunicazione tra agenti avviene tramite input/output ben definiti, con notifiche in tempo reale e audit '
#  'trail completo. L’isolamento delle operazioni in sandbox, insieme a politiche di accesso controllato, garantisce la conformità a normative come '
#  'GDPR e ISO/IEC\u202f27001.\n'
#  '3. **Scalabilità e integrazione** – l’architettura è pronta per l’uso su orchestratori distribuiti (Celery, Airflow, Kubernetes) e può essere '
#  'estesa a ambienti edge e serverless, aprendo la strada a scenari IoT e analisi in tempo reale.\n'
#  '4. **Estendibilità e interoperabilità** – la possibilità di creare planner personalizzati, listener WebSocket e nuovi tool permette di adattare '
#  'CrewAI a casi d’uso specifici, promuovendo al contempo un marketplace di agenti pre‑pacchettati.\n'
#  '\n'
#  'Guardando al futuro, CrewAI mira a trasformarsi in un vero e proprio ecosistema di AI collaborativa. Le roadmap prevedono l’integrazione di '
#  'meta‑learning per l’auto‑ottimizzazione della composizione degli agenti, l’adozione di blockchain per audit trail immutabili, l’espansione verso '
#  'ambienti multi‑cloud e edge, nonché l’integrazione di modelli multimodali (vision‑language, audio‑text) e tecniche di federated learning per '
#  'preservare la privacy dei dati.\n'
#  '\n'
#  'In sintesi, CrewAI non è soltanto un tool di orchestrazione; è un paradigma che consente ai team di sviluppo e data scientist di concentrarsi '
#  'sulle competenze specifiche dei modelli, lasciando l’architettura, la sicurezza e la scalabilità al framework. La comunità open‑source, i plugin e '
#  'le certificazioni previste garantiranno che il framework rimanga all’avanguardia, pronto a rispondere alle esigenze emergenti del panorama AI.\n'
#  '\n'
#  '[CODICE_RICHIESTO][START] Scrivi un esempio di codice Python che mostra come inizializzare un Crew con due agenti (DataAnalyst e Summarizer), '
#  'definire un task di analisi dei dati, eseguire il task con logging e un listener WebSocket per ricevere aggiornamenti in tempo reale. [END]')
# '------------------------------------------------------------------------------------------------------------------------------------------------------'
# ''

# %%
pprint.pprint(crew2.flow.state.code_snippets['Introduzione'])
# Out:
# ('```python\n'
#  '"""\n'
#  'CrewAI example: Exploratory Data Analysis and Summary Report\n'
#  '============================================================\n'
#  '\n'
#  'This script demonstrates how to use the `crewai` library to orchestrate\n'
#  'two agents – a Data Analyst and a Summarizer – in a sequential workflow.\n'
#  'It generates a synthetic dataset, runs an exploratory data analysis,\n'
#  'and finally produces a concise summary report.\n'
#  '\n'
#  'The code follows best practices such as:\n'
#  '\n'
#  '* type‑annotated functions\n'
#  '* proper logging instead of bare ``print`` statements\n'
#  '* reproducible random data generation\n'
#  '* clear separation of concerns\n'
#  '* comprehensive docstrings\n'
#  '"""\n'
#  '\n'
#  'import logging\n'
#  'import random\n'
#  'from typing import Tuple\n'
#  '\n'
#  'import numpy as np\n'
#  'import pandas as pd\n'
#  'from crewai import Agent, Crew, Process, Task\n'
#  '\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  '# Configuration\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  '\n'
#  '# Reproducibility\n'
#  'SEED = 42\n'
#  'random.seed(SEED)\n'
#  'np.random.seed(SEED)\n'
#  '\n'
#  '# Logging configuration\n'
#  'logging.basicConfig(\n'
#  '    level=logging.INFO,\n'
#  '    format="%(asctime)s [%(levelname)s] %(message)s",\n'
#  '    datefmt="%H:%M:%S",\n'
#  ')\n'
#  'logger = logging.getLogger(__name__)\n'
#  '\n'
#  '\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  '# Helper functions\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  'def create_dataset(n_samples: int = 10) -> pd.DataFrame:\n'
#  '    """\n'
#  '    Generate a synthetic dataset containing sales, profit and region.\n'
#  '\n'
#  '    Parameters\n'
#  '    ----------\n'
#  '    n_samples : int, default 10\n'
#  '        Number of rows in the generated DataFrame.\n'
#  '\n'
#  '    Returns\n'
#  '    -------\n'
#  '    pd.DataFrame\n'
#  '        DataFrame with columns ``Sales``, ``Profit`` and ``Region``.\n'
#  '    """\n'
#  '    logger.debug("Generating synthetic dataset with %d samples", n_samples)\n'
#  '    data = {\n'
#  '        "Sales": np.random.randint(50, 200, n_samples),\n'
#  '        "Profit": np.random.uniform(5.0, 20.0, n_samples),\n'
#  '        "Region": np.random.choice(["North", "South", "East", "West"], '
#  'n_samples),\n'
#  '    }\n'
#  '    return pd.DataFrame(data)\n'
#  '\n'
#  '\n'
#  'def create_agents() -> Tuple[Agent, Agent]:\n'
#  '    """\n'
#  '    Instantiate the two agents used in the crew.\n'
#  '\n'
#  '    Returns\n'
#  '    -------\n'
#  '    tuple[Agent, Agent]\n'
#  '        The first element is the Data Analyst, the second is the '
#  'Summarizer.\n'
#  '    """\n'
#  '    data_analyst = Agent(\n'
#  '        role="Data Analyst",\n'
#  '        goal="Perform exploratory data analysis on the dataset and generate '
#  'insights.",\n'
#  '        backstory="Experienced in statistical analysis and data '
#  'visualization.",\n'
#  '        verbose=True,\n'
#  '        allow_delegation=False,\n'
#  '    )\n'
#  '\n'
#  '    summarizer = Agent(\n'
#  '        role="Summarizer",\n'
#  '        goal="Summarize the insights from the Data Analyst into a concise '
#  'report.",\n'
#  '        backstory="Skilled in clear communication and report writing.",\n'
#  '        verbose=True,\n'
#  '        allow_delegation=False,\n'
#  '    )\n'
#  '    return data_analyst, summarizer\n'
#  '\n'
#  '\n'
#  'def create_tasks(df: pd.DataFrame, analyst: Agent, summarizer: Agent) -> '
#  'list[Task]:\n'
#  '    """\n'
#  '    Build the list of tasks for the crew.\n'
#  '\n'
#  '    Parameters\n'
#  '    ----------\n'
#  '    df : pd.DataFrame\n'
#  '        The dataset to be analysed.\n'
#  '    analyst : Agent\n'
#  '        The agent that will perform the analysis.\n'
#  '    summarizer : Agent\n'
#  '        The agent that will produce the summary.\n'
#  '\n'
#  '    Returns\n'
#  '    -------\n'
#  '    list[Task]\n'
#  '        Ordered list of tasks: analysis followed by summarisation.\n'
#  '    """\n'
#  '    # Convert the first few rows to a human‑readable string for the context\n'
#  '    context_head = df.head().to_string(index=False)\n'
#  '\n'
#  '    analysis_task = Task(\n'
#  '        description="Analyze the dataset and provide key findings.",\n'
#  '        expected_output="A detailed analysis of the dataset.",\n'
#  '        agent=analyst,\n'
#  '        context=context_head,\n'
#  '    )\n'
#  '\n'
#  '    summary_task = Task(\n'
#  '        description="Create a summary report based on the analysis.",\n'
#  '        expected_output="A concise summary report.",\n'
#  '        agent=summarizer,\n'
#  '        context="The analysis results from the previous step.",\n'
#  '    )\n'
#  '\n'
#  '    return [analysis_task, summary_task]\n'
#  '\n'
#  '\n'
#  'def run_crew(df: pd.DataFrame, tasks: list[Task]) -> str:\n'
#  '    """\n'
#  '    Execute the crew workflow and return the final report.\n'
#  '\n'
#  '    Parameters\n'
#  '    ----------\n'
#  '    df : pd.DataFrame\n'
#  '        Dataset (unused here but kept for potential future use).\n'
#  '    tasks : list[Task]\n'
#  '        Ordered list of tasks to execute.\n'
#  '\n'
#  '    Returns\n'
#  '    -------\n'
#  '    str\n'
#  '        Final report produced by the summariser.\n'
#  '    """\n'
#  '    agents = [task.agent for task in tasks]\n'
#  '    crew = Crew(\n'
#  '        agents=agents,\n'
#  '        tasks=tasks,\n'
#  '        process=Process.sequential,\n'
#  '        verbose=2,\n'
#  '    )\n'
#  '\n'
#  '    logger.info("Starting crew kickoff")\n'
#  '    result = crew.kickoff()\n'
#  '    logger.info("Crew execution finished")\n'
#  '    return result\n'
#  '\n'
#  '\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  '# Main entry point\n'
#  '# '
#  '--------------------------------------------------------------------------- '
#  '#\n'
#  'def main() -> None:\n'
#  '    """\n'
#  '    Orchestrate the end‑to‑end workflow:\n'
#  '    1. Create dataset\n'
#  '    2. Instantiate agents\n'
#  '    3. Build tasks\n'
#  '    4. Run crew\n'
#  '    5. Print final report\n'
#  '    """\n'
#  '    df = create_dataset()\n'
#  '    analyst, summarizer = create_agents()\n'
#  '    tasks = create_tasks(df, analyst, summarizer)\n'
#  '\n'
#  '    try:\n'
#  '        final_report = run_crew(df, tasks)\n'
#  '    except Exception as exc:  # pragma: no cover\n'
#  '        logger.exception("Crew execution failed: %s", exc)\n'
#  '        raise\n'
#  '\n'
#  '    print("\\nFinal Report:\\n", final_report)\n'
#  '\n'
#  '\n'
#  'if __name__ == "__main__":  # pragma: no cover\n'
#  '    main()\n'
#  '```')

# %%
# pprint.pprint(crew2.flow.state.section_summaries, width=l_str)
pprint.pprint(crew2.flow.state.code_snippets, width=l_str)

# %%
print(crew2.flow.state.__dict__['code_instructions']['Introduzione'])
